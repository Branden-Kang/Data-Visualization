# %% [markdown]
# [Reference](https://towardsdatascience.com/data-dashboard-python-package-for-eda-and-baseline-ml-model-creation-f10840a6cea0)

# %%
pip install data-dashboard
# Out:
# ...
#      |████████████████████████████████| 84 kB 1.9 MB/s
# ...
#      |████████████████████████████████| 38.1 MB 1.3 MB/s
# ...
#      |████████████████████████████████| 173.5 MB 10 kB/s
# ...
#      |████████████████████████████████| 2.0 MB 40.4 MB/s
# ...
#      |████████████████████████████████| 11.3 MB 28.4 MB/s
# ...
#      |████████████████████████████████| 97 kB 3.9 MB/s
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.1.5
#     Uninstalling pandas-1.1.5:
#       Successfully uninstalled pandas-1.1.5
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 0.90
#     Uninstalling xgboost-0.90:
#       Successfully uninstalled xgboost-0.90
#   Attempting uninstall: lightgbm
#     Found existing installation: lightgbm 2.2.3
#     Uninstalling lightgbm-2.2.3:
#       Successfully uninstalled lightgbm-2.2.3
# ...

# %%
from data_dashboard import Dashboard
from data_dashboard.examples import iris
output_directory = "output/dashboard_output"
X, y, descriptions = iris()
# descriptions is an optional argument, more in documentation
dsh = Dashboard(X, y, output_directory, descriptions)  
dsh.create_dashboard()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:2593: UserWarning: n_quantiles (1000) is greater than the total number of samples (112). n_quantiles is set to n_samples.
#   "n_samples." % (self.n_quantiles, n_samples)
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:2593: UserWarning: n_quantiles (1000) is greater than the total number of samples (150). n_quantiles is set to n_samples.
#   "n_samples." % (self.n_quantiles, n_samples)
# [13:08:15] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Found model: SGDClassifier
# Creating Dashboard...
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# Created output at output/dashboard_output
