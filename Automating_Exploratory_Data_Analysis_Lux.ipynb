# %% [markdown]
# [Reference](https://medium.com/swlh/automating-exploratory-data-analysis-part-3-d04352b83072)

# %%
pip install lux
# Out:
# ...
#      |████████████████████████████████| 354 kB 45.0 MB/s
# ...
#      |████████████████████████████████| 40 kB 6.1 MB/s
# ...
#   Using cached pulsar-2.0.2-py3-none-any.whl (280 kB)
# ...
#   Using cached multidict-5.2.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (160 kB)
# ...
#   Created wheel for pulsar-odm: filename=pulsar_odm-0.7.0-py3-none-any.whl size=17003 sha256=63d3386dd19709eb90bb2e096dc4717f4413031317e49a3119e2fcecc979e80f
#   Stored in directory: /root/.cache/pip/wheels/32/24/d8/2e559a0d244f6998e03186b4b4b4b937c6e90a5d7697b627fb
# Successfully built pulsar-odm
# ...

# %%
import pandas as pd
import lux

# %%
df = pd.read_csv("https://raw.githubusercontent.com/lux-org/lux-datasets/master/data/car.csv")

# %%
df
# Out:
#                           Name  MilesPerGal  ...  Origin       Brand
# 0    chevrolet chevelle malibu         18.0  ...     USA   chevrolet
# 1            buick skylark 320         15.0  ...     USA       buick
# 2           plymouth satellite         18.0  ...     USA    plymouth
# 3                amc rebel sst         16.0  ...     USA         amc
# 4                  ford torino         17.0  ...     USA        ford
# ..                         ...          ...  ...     ...         ...
# 387            ford mustang gl         27.0  ...     USA        ford
# 388                  vw pickup         44.0  ...  Europe  volkswagen
# 389              dodge rampage         32.0  ...     USA       dodge
# 390                ford ranger         28.0  ...     USA        ford
# 391                 chevy s-10         31.0  ...     USA   chevrolet
#
# [392 rows x 10 columns]

# %%
df.intent = ["MilesPerGal","Acceleration"]
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.
#                           Name  MilesPerGal  ...  Origin       Brand
# 0    chevrolet chevelle malibu         18.0  ...     USA   chevrolet
# 1            buick skylark 320         15.0  ...     USA       buick
# 2           plymouth satellite         18.0  ...     USA    plymouth
# 3                amc rebel sst         16.0  ...     USA         amc
# 4                  ford torino         17.0  ...     USA        ford
# ..                         ...          ...  ...     ...         ...
# 387            ford mustang gl         27.0  ...     USA        ford
# 388                  vw pickup         44.0  ...  Europe  volkswagen
# 389              dodge rampage         32.0  ...     USA       dodge
# ...
