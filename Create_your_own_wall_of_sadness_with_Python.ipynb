# %% [markdown]
# [Reference](https://medium.com/@thiagoalves/create-your-own-wall-of-sadness-with-python-16e00077c8a1)

# %% [markdown]
# # Preprocessing

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import pandas as pd
import plotly.express as px
import numpy as np

# %%
# columns_to_select = ['Date', 'Symbol', 'Open', 'Close']
# sp500_daily_df = pd.read_csv('./datasets/sp500_stocks.csv')[columns_to_select]

# sum_per_day_df = sp500_daily_df.groupby('Date').sum().reset_index()
# sum_per_day_df['Net'] = sum_per_day_df['Close'] - sum_per_day_df['Open']
# sum_per_day_df.sort_values('Net').head()

# worst_day = '2020-03-20'
# worst_day_df = sp500_daily_df[sp500_daily_df['Date'] == worst_day]
# worst_day_df.head()

# %% [markdown]
# # Enriching the dataset

# %%
# columns_to_select = ['Symbol', 'Shortname', 'Sector', 'Weight']
# company_details_df = pd.read_csv('./datasets/sp500_companies.csv')[columns_to_select]

# worst_day_enriched_df = (worst_day_df.set_index('Symbol')
#                          .join(company_details_df.set_index('Symbol'))
#                          .reset_index()
#                          .dropna())
# worst_day_enriched_df.head()

# %%
# worst_day_enriched_df['PcChangeDay'] = ((worst_day_enriched_df['Close'] 
#                                          - worst_day_enriched_df['Open'])
#                                          / worst_day_enriched_df['Open'] 
#                                         * 100
#                                        ).round(2)
# worst_day_enriched_df.head()

# %%
# worst_day_enriched_df.to_csv('./datasets/worst_day_sp500.csv', index=False)

# %% [markdown]
# # Creating the treemap chart

# %%
worst_day_sp500_df = pd.read_csv('https://raw.githubusercontent.com/avsthiago/projects/main/wall-of-sadness/datasets/worst_day_sp500.csv')

# %%
fig = px.treemap(worst_day_sp500_df, 
                 path=[px.Constant('Stocks'), 'Sector',  'Symbol'],
                 values='Weight', color='PcChangeDay',
                 color_continuous_scale=[ 'Red', "#8b0000", 'Green'])
fig.update_layout(margin = dict(t=30, l=10, r=10, b=10))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="8c88610b-ed08-4391-bce1-186a91b622d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8c88610b-ed08-4391-bce1-186a91b622d6")) {                    Plotly.newPlot(                        "8c88610b-ed08-4391-bce1-186a91b622d6",                        [{"branchvalues":"total","customdata":[[0.71],[-2.54],[-13.250000000000002],[-7.26],[-5.73],[-7.17],[-8.18],[-8.17],[-4.82],[-5.62],[-7.930000000000001],[-9.68],[-5.77],[-2.27],[-11.989999999999998],[-11.74],[5.89],[-2.16],[-7.59],[9.19],[4.15],[-8.5],[-14.73],[-0.09],[-8.36],[-3.26],[-13.97],[-8.44],[-0.95],[-4.58],[-10.38],[-5.35],[-7.66],[-5.609999999999999],[-4.16],[-8.89],[-7.01],[-2.0],[-6.41],[-0.9499999999999998],[1.8],[7.42],[-7.690000000000001],[-12.8],[-5.789999999999999],[-10.9],[-4.84],[-12.19],[-12.53],[-6.15],[-12.3],[-4.85],[-9.6],[-1.43],[-9.700000000000001],[-7.12],[1.06],[-13.02],[-14.06],[-3.21],[-5.28],[-4.06],[-3.2],[-1.86],[-11.539999999999997],[-1.33],[-3.27],[-3.5399999999999996],[-2.92],[-4.86],[-4.25],[-5.57],[-5.93],[-0.99],[-3.35],[-1.92],[-7.39],[2.59],[-4.28],[-14.860000000000001],[-0.9700000000000001],[8.21],[3.6500000000000004],[-3.1999999999999997],[-11.26],[-0.48],[-5.44],[-1.35],[-0.38
# %%
# this sorting is important otherwise the values from the df 
# and the customdata would get messy
worst_day_sp500_df.sort_values(by=['Symbol','Sector'],inplace=True)

fig = px.treemap(worst_day_sp500_df, 
                 path=[px.Constant('Stocks'), 'Sector',  'Symbol'],
                 values='Weight', color='PcChangeDay',
                 color_continuous_scale=[ 'Red', "#8b0000", 'Green'])

# you can change the index if you have multiple plots
fig.data[0].customdata = worst_day_sp500_df['PcChangeDay']
# We use <br> here to break the line between the symbol (label) 
# and the daily change that we passed to the customdata above
fig.data[0].texttemplate = "%{label}<br>%{customdata}"
fig.update_traces(textposition="middle center", 
                  selector=dict(type='treemap'))
fig.update_layout(margin = dict(t=30, l=10, r=10, b=10))
# This line removes the the color scale from the chart
fig.update(layout_coloraxis_showscale=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="2b0424a0-6806-492f-9f66-3d9b634b4301" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2b0424a0-6806-492f-9f66-3d9b634b4301")) {                    Plotly.newPlot(                        "2b0424a0-6806-492f-9f66-3d9b634b4301",                        [{"branchvalues":"total","customdata":[0.71,-2.54,-13.25,-7.26,-5.73,-7.17,-8.18,-8.17,-4.82,-5.62,-7.93,-9.68,-5.77,-2.27,-11.99,-11.74,5.89,-2.16,-7.59,9.19,4.15,-8.5,-14.73,-0.09,-8.36,-3.26,-13.97,-8.44,-0.95,-4.58,-10.38,-5.35,-7.66,-5.61,-4.16,-8.89,-7.01,-2.0,-6.41,-0.95,1.8,7.42,-7.69,-12.8,-5.79,-10.9,-4.84,-12.19,-12.53,-6.15,-12.3,-4.85,-9.6,-1.43,-9.7,-7.12,1.06,-13.02,-14.06,-3.21,-5.28,-4.06,-3.2,-1.86,-11.54,-1.33,-3.27,-3.54,-2.92,-4.86,-4.25,-5.57,-5.93,-0.99,-3.35,-1.92,-7.39,2.59,-4.28,-14.86,-0.97,8.21,3.65,-3.2,-11.26,-0.48,-5.44,-1.35,-0.38,-1.02,-5.85,-4.84,-8.46,-6.98,-6.93,-1.13,-7.54,2.09,-1.37,-3.66,-11.44,-10.33,-0.08,-6.23,-9.9,-0.81,-5.68,-3.88,-15.86,-8.61,-5.53,-0.76,-6.98,-8.51,-2.82,-3.78,-10.93,-4.79,-2.89,-5.29,-1.99,-0.24,3.64,-6.66,-7.85,-3.26,-6.71,-14.98,-1.59,-7.16,1.49,-1.64,-10.43,-0.89,-3.77,5.4,-7.88,-4.02,-8.25,-5.03,-14.29,-4.17,-9.82,-8.79,-9.79,-9.88,0.57,-5.75,-6.51,-11.0,-10.65,-9.7,-4.11,-4.76,-3.09,-5.18,-6.07,0.58,-0.55,-7.86,-8.29,-11.83,-7.39,-12.09,-6.68,-11.68,-13.89,-8.22,-5.11,-6.25,-3.17,-8.08,-4.63,-3.88,-11.19,-5.82,-9.06,-6.91,-2.48,-4.7,0.65,-3.27,-6.13,-3.08,-5.4,-4.59,-10.09,-9.41,-12.09,-6.46,-3.16,-3.53,-3.55,-6.99,-7.85,0.7,-4.97,-11.66,-1.52,-5.43,-5.58,-5.54,-15.06,-10.44,-6.8,-7.1,-9.19,-1.56,-3.9,-2.31,-