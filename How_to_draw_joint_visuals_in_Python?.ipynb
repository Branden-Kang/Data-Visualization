# %% [markdown]
# [Reference](https://towardsdev.com/how-to-draw-joint-visuals-in-python-a7f9cb54540)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 
import palettable
from pandas import Series,DataFrame
import seaborn as sns
import palettable

# %%
iris = sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.set(style="white",font_scale=1.5)
g = sns.jointplot(x='sepal_length', y='sepal_width', data=iris,
                 color='#098154',
                 )
g.fig.set_size_inches(10,8)

# %%
sns.set(style="white",font_scale=1.5)
g = sns.jointplot(x='sepal_length', y='sepal_width', data=iris,
                  color='#098154',
                  height=5, # Center plot height
                  ratio=2,  # The ratio of center plot and side plots
                  marker='^',
                 )
g.fig.set_size_inches(10,8)

# %%
sns.set(style="white",font_scale=1.5)
g = sns.jointplot(x='sepal_length', y='sepal_width', data=iris,
                  color='#098154',
                  marginal_kws=dict(bins=15, # Bin numbers
                                    kde=True,# Apply KDE
                                    color='#c72e29',                                   
                                   ),
                 )
g.fig.set_size_inches(10,8)

# %%
for t in ['scatter', 'reg', 'resid', 'kde', 'hex']:
    sns.set(style="white",font_scale=1.5)
    g = sns.jointplot(x='sepal_length', y='sepal_width', data=iris,
                      color='#098154',
                      kind=t,
                     )
    g.fig.suptitle('Center of {}'.format(t))
    g.fig.set_size_inches(10,8)

# %%
g = sns.JointGrid(x='sepal_length', y='sepal_width', data=iris) # This is a figure
g = g.plot(sns.regplot, sns.distplot,) # Draw 3 visuals on the figure
g.fig.set_size_inches(10,8)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:1689: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)

# %%
g = sns.JointGrid(x='sepal_length', y='sepal_width', data=iris)
g.fig.set_size_inches(10,8)
g = g.plot_joint(sns.scatterplot, color='g', marker='^', s=200)
g = g.plot_marginals(sns.distplot, kde=True, color='#c72e29')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:1689: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)

# %%
g = sns.JointGrid(x='sepal_length', y='sepal_width', data=iris, space=0)
g.fig.set_size_inches(10,8)
g = g.plot_joint(sns.scatterplot, color='g',marker='*',s=200)

# x axis
g.ax_marg_x.hist(iris['sepal_length'], color='#01a2d9', alpha=1,
                 bins=15,
                 
                )

# y axis
g.ax_marg_y.hist(iris['sepal_width'], color='#c72e29', alpha=1,
                    orientation="horizontal",
                   bins=15)
plt.show()
