# %% [markdown]
# [Reference](https://towardsdatascience.com/getting-started-with-powerful-data-tables-in-your-python-web-apps-1e48dc44caf2)

# %%
pip install reflex
# Out:
# Collecting reflex
#   Downloading reflex-0.6.2.post1-py3-none-any.whl.metadata (11 kB)
# Collecting alembic<2.0,>=1.11.1 (from reflex)
#   Downloading alembic-1.13.3-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: build<2.0,>=1.0.3 in /usr/local/lib/python3.10/dist-packages (from reflex) (1.2.2.post1)
# Requirement already satisfied: charset-normalizer<4.0,>=3.3.2 in /usr/local/lib/python3.10/dist-packages (from reflex) (3.3.2)
# Collecting distro<2.0,>=1.8.0 (from reflex)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting fastapi!=0.111.0,!=0.111.1,>=0.96.0 (from reflex)
#   Downloading fastapi-0.115.0-py3-none-any.whl.metadata (27 kB)
# Collecting gunicorn<24.0,>=20.1.0 (from reflex)
#   Downloading gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting httpx<1.0,>=0.25.1 (from reflex)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: jinja2<4.0,>=3.1.2 in /usr/local/lib/python3.10/dist-packages (from reflex) (3.1.4)
# Requirement already satisfied: lazy_loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from reflex) (0.4)
# Requirement already satisfied: packaging<25.0,>=23.1 in /usr/local/lib/python3.10/dist-packages (from reflex) (24.1)
# Requirement already satisfied: platformdirs<5.0,>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from reflex) (4.3.6)
# Requirement already satisfied: psutil<7.0,>=5.9.4 in /usr/local/lib/python3.10/dist-packages (from reflex) (5.9.5)
# Requirement already satisfied: pydantic<3.0,>=1.10.2 in /usr/local/lib/python3.10/dist-packages (from reflex) (2.9.2)
# Collecting python-engineio!=4.6.0 (from reflex)
#   Downloading python_engineio-4.9.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting python-multipart<0.1,>=0.0.5 (from reflex)
#   Downloading python_multipart-0.0.12-py3-none-any.whl.metadata (1.9 kB)
# Collecting python-socketio<6.0,>=5.7.0 (from reflex)
#   Downloading python_socketio-5.11.4-py3-none-any.whl.metadata (3.2 kB)
# Collecting redis<6.0,>=4.3.5 (from reflex)
#   Downloading redis-5.1.1-py3-none-any.whl.metadata (9.1 kB)
# Collecting reflex-chakra>=0.6.0 (from reflex)
#   Downloading reflex_chakra-0.6.1-py3-none-any.whl.metadata (1.3 kB)
# Collecting reflex-hosting-cli<2.0,>=0.1.2 (from reflex)
#   Downloading reflex_hosting_cli-0.1.13-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: rich<14.0,>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from reflex) (13.9.2)
# Collecting setuptools<70.2,>=69.1.1 (from reflex)
#   Downloading setuptools-70.1.1-py3-none-any.whl.metadata (6.0 kB)
# Collecting sqlmodel<0.1,>=0.0.14 (from reflex)
#   Downloading sqlmodel-0.0.22-py3-none-any.whl.metadata (10 kB)
# Collecting starlette-admin<1.0,>=0.11.0 (from reflex)
#   Downloading starlette_admin-0.14.1-py3-none-any.whl.metadata (8.1 kB)
# Collecting tomlkit<1.0,>=0.12.4 (from reflex)
#   Downloading tomlkit-0.13.2-py3-none-any.whl.metadata (2.7 kB)
# Collecting twine<6.0,>=4.0.0 (from reflex)
#   Downloading twine-5.1.1-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: typer<1.0,>=0.4.2 in /usr/local/lib/python3.10/dist-packages (from reflex) (0.12.5)
# Collecting uvicorn>=0.20.0 (from reflex)
#   Downloading uvicorn-0.31.1-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: wheel<1.0,>=0.42.0 in /usr/local/lib/python3.10/dist-packages (from reflex) (0.44.0)
# Requirement already satisfied: wrapt<2.0,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from reflex) (1.16.0)
# Requirement already satisfied: SQLAlchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from alembic<2.0,>=1.11.1->reflex) (2.0.35)
# Collecting Mako (from alembic<2.0,>=1.11.1->reflex)
#   Downloading Mako-1.3.5-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic<2.0,>=1.11.1->reflex) (4.12.2)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.10/dist-packages (from build<2.0,>=1.0.3->reflex) (1.2.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from build<2.0,>=1.0.3->reflex) (2.0.2)
# Collecting starlette<0.39.0,>=0.37.2 (from fastapi!=0.111.0,!=0.111.1,>=0.96.0->reflex)
#   Downloading starlette-0.38.6-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1.0,>=0.25.1->reflex) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1.0,>=0.25.1->reflex) (2024.8.30)
# Collecting httpcore==1.* (from httpx<1.0,>=0.25.1->reflex)
#   Downloading httpcore-1.0.6-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx<1.0,>=0.25.1->reflex) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<1.0,>=0.25.1->reflex) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1.0,>=0.25.1->reflex)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2<4.0,>=3.1.2->reflex) (2.1.5)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0,>=1.10.2->reflex) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0,>=1.10.2->reflex) (2.23.4)
# Collecting simple-websocket>=0.10.0 (from python-engineio!=4.6.0->reflex)
#   Downloading simple_websocket-1.0.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting bidict>=0.21.0 (from python-socketio<6.0,>=5.7.0->reflex)
#   Downloading bidict-0.23.1-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: async-timeout>=4.0.3 in /usr/local/lib/python3.10/dist-packages (from redis<6.0,>=4.3.5->reflex) (4.0.3)
# Collecting pipdeptree<2.17.0,>=2.13.1 (from reflex-hosting-cli<2.0,>=0.1.2->reflex)
#   Downloading pipdeptree-2.16.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from reflex-hosting-cli<2.0,>=0.1.2->reflex) (2.8.2)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from reflex-hosting-cli<2.0,>=0.1.2->reflex) (0.9.0)
# Collecting websockets>=10.4 (from reflex-hosting-cli<2.0,>=0.1.2->reflex)
#   Downloading websockets-13.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0,>=13.0.0->reflex) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0,>=13.0.0->reflex) (2.18.0)
# Collecting pkginfo>=1.8.1 (from twine<6.0,>=4.0.0->reflex)
#   Downloading pkginfo-1.11.2-py3-none-any.whl.metadata (11 kB)
# Collecting readme-renderer>=35.0 (from twine<6.0,>=4.0.0->reflex)
#   Downloading readme_renderer-44.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from twine<6.0,>=4.0.0->reflex) (2.32.3)
# Collecting requests-toolbelt!=0.9.0,>=0.8.0 (from twine<6.0,>=4.0.0->reflex)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from twine<6.0,>=4.0.0->reflex) (2.2.3)
# Requirement already satisfied: importlib-metadata>=3.6 in /usr/local/lib/python3.10/dist-packages (from twine<6.0,>=4.0.0->reflex) (8.4.0)
# Requirement already satisfied: keyring>=15.1 in /usr/lib/python3/dist-packages (from twine<6.0,>=4.0.0->reflex) (23.5.0)
# Collecting rfc3986>=1.4.0 (from twine<6.0,>=4.0.0->reflex)
#   Downloading rfc3986-2.0.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Collecting pkginfo>=1.8.1 (from twine<6.0,>=4.0.0->reflex)
#   Downloading pkginfo-1.10.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.4.2->reflex) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.4.2->reflex) (1.5.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=3.6->twine<6.0,>=4.0.0->reflex) (3.20.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14.0,>=13.0.0->reflex) (0.1.2)
# Requirement already satisfied: pip>=23.1.2 in /usr/local/lib/python3.10/dist-packages (from pipdeptree<2.17.0,>=2.13.1->reflex-hosting-cli<2.0,>=0.1.2->reflex) (24.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->reflex-hosting-cli<2.0,>=0.1.2->reflex) (1.16.0)
# Collecting nh3>=0.2.14 (from readme-renderer>=35.0->twine<6.0,>=4.0.0->reflex)
#   Downloading nh3-0.2.18-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting docutils>=0.21.2 (from readme-renderer>=35.0->twine<6.0,>=4.0.0->reflex)
#   Downloading docutils-0.21.2-py3-none-any.whl.metadata (2.8 kB)
# Collecting wsproto (from simple-websocket>=0.10.0->python-engineio!=4.6.0->reflex)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy>=1.3.0->alembic<2.0,>=1.11.1->reflex) (3.1.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1.0,>=0.25.1->reflex) (1.2.2)
# Downloading reflex-0.6.2.post1-py3-none-any.whl (706 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.9/706.9 kB 11.0 MB/s eta 0:00:00
# Downloading alembic-1.13.3-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.2/233.2 kB 12.4 MB/s eta 0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading fastapi-0.115.0-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 kB 5.7 MB/s eta 0:00:00
# Downloading gunicorn-23.0.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 6.0 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 4.7 MB/s eta 0:00:00
# Downloading httpcore-1.0.6-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 4.1 MB/s eta 0:00:00
# Downloading python_engineio-4.9.1-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 1.8 MB/s eta 0:00:00
# Downloading python_multipart-0.0.12-py3-none-any.whl (23 kB)
# Downloading python_socketio-5.11.4-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.2/76.2 kB 3.9 MB/s eta 0:00:00
# Downloading redis-5.1.1-py3-none-any.whl (261 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.3/261.3 kB 13.5 MB/s eta 0:00:00
# Downloading reflex_chakra-0.6.1-py3-none-any.whl (174 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.8/174.8 kB 9.0 MB/s eta 0:00:00
# Downloading reflex_hosting_cli-0.1.13-py3-none-any.whl (32 kB)
# Downloading setuptools-70.1.1-py3-none-any.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.3/883.3 kB 28.6 MB/s eta 0:00:00
# Downloading sqlmodel-0.0.22-py3-none-any.whl (28 kB)
# Downloading starlette_admin-0.14.1-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 39.3 MB/s eta 0:00:00
# Downloading tomlkit-0.13.2-py3-none-any.whl (37 kB)
# Downloading twine-5.1.1-py3-none-any.whl (38 kB)
# Downloading uvicorn-0.31.1-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 2.7 MB/s eta 0:00:00
# Downloading bidict-0.23.1-py3-none-any.whl (32 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.2 MB/s eta 0:00:00
# Downloading pipdeptree-2.16.2-py3-none-any.whl (27 kB)
# Downloading pkginfo-1.10.0-py3-none-any.whl (30 kB)
# Downloading readme_renderer-44.0-py3-none-any.whl (13 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.1 MB/s eta 0:00:00
# Downloading rfc3986-2.0.0-py2.py3-none-any.whl (31 kB)
# Downloading simple_websocket-1.0.0-py3-none-any.whl (13 kB)
# Downloading starlette-0.38.6-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 3.6 MB/s eta 0:00:00
# Downloading websockets-13.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (164 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.1/164.1 kB 7.6 MB/s eta 0:00:00
# Downloading Mako-1.3.5-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 5.1 MB/s eta 0:00:00
# Downloading docutils-0.21.2-py3-none-any.whl (587 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.4/587.4 kB 23.0 MB/s eta 0:00:00
# Downloading nh3-0.2.18-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (769 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 769.2/769.2 kB 21.1 MB/s eta 0:00:00
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Installing collected packages: nh3, websockets, tomlkit, setuptools, rfc3986, redis, python-multipart, pkginfo, pipdeptree, Mako, h11, gunicorn, docutils, distro, bidict, wsproto, uvicorn, starlette, requests-toolbelt, readme-renderer, httpcore, alembic, twine, starlette-admin, sqlmodel, simple-websocket, httpx, fastapi, reflex-hosting-cli, python-engineio, python-socketio, reflex-chakra, reflex
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 71.0.4
#     Uninstalling setuptools-71.0.4:
#       Successfully uninstalled setuptools-71.0.4
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.18.1
#     Uninstalling docutils-0.18.1:
#       Successfully uninstalled docutils-0.18.1
#   Attempting uninstall: distro
#     Found existing installation: distro 1.7.0
#     Uninstalling distro-1.7.0:
#       Successfully uninstalled distro-1.7.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# sphinx 5.0.2 requires docutils<0.19,>=0.14, but you have docutils 0.21.2 which is incompatible.
# Successfully installed Mako-1.3.5 alembic-1.13.3 bidict-0.23.1 distro-1.9.0 docutils-0.21.2 fastapi-0.115.0 gunicorn-23.0.0 h11-0.14.0 httpcore-1.0.6 httpx-0.27.2 nh3-0.2.18 pipdeptree-2.16.2 pkginfo-1.10.0 python-engineio-4.9.1 python-multipart-0.0.12 python-socketio-5.11.4 readme-renderer-44.0 redis-5.1.1 reflex-0.6.2.post1 reflex-chakra-0.6.1 reflex-hosting-cli-0.1.13 requests-toolbelt-1.0.0 rfc3986-2.0.0 setuptools-70.1.1 simple-websocket-1.0.0 sqlmodel-0.0.22 starlette-0.38.6 starlette-admin-0.14.1 tomlkit-0.13.2 twine-5.1.1 uvicorn-0.31.1 websockets-13.1 wsproto-1.2.0

# %%
pip install reflex_ag_grid
# Out:
# Collecting reflex_ag_grid
#   Downloading reflex_ag_grid-0.0.7-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: reflex>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from reflex_ag_grid) (0.6.2.post1)
# Requirement already satisfied: alembic<2.0,>=1.11.1 in /usr/local/lib/python3.10/dist-packages (from reflex>=0.6.0->reflex_ag_grid) (1.13.3)
# Requirement already satisfied: build<2.0,>=1.0.3 in /usr/local/lib/python3.10/dist-packages (from reflex>=0.6.0->reflex_ag_grid) (1.2.2.post1)
# Requirement already satisfied: charset-normalizer<4.0,>=3.3.2 in /usr/local/lib/python3.10/dist-packages (from reflex>=0.6.0->reflex_ag_grid) (3.3.2)
# Requirement already satisfied: distro<2.0,>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from reflex>=0.6.0->reflex_ag_grid) (1.9.0)
# Requirement already satisfied: fastapi!=0.111.0,!=0.111.1,>=0.96.0 in /usr/local/lib/python3.10/dist-packages (from reflex>=0.6.0->reflex_ag_grid) (0.115.0)
# Requirement already satisfied: gunicorn<24.0,>=20.1.0 in /usr/local/lib/python3.10/dist-packages (from reflex>=0.6.0->reflex_ag_grid) (23.0.0)
# Requirement already satisfied: httpx<1.0,>=0.25.1 in /usr/local/lib/python3.10/dist-packages (from reflex>=0.6.0->reflex_ag_grid) (0.27.2)
# Requirement already satisfied: jinja2<4.0,>=3.1.2 in /usr/local/lib/python3.10/dist-packages (from reflex>=0.6.0->reflex_ag_grid) (3.1.4)
# Requirement already satisfied: lazy_loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from reflex>=0.6.0->reflex_ag_grid) (0.4)
# Requirement already satisfied: packaging<25.0,>=23.1 in /usr/local/lib/python3.10/dist-packages (from reflex>=0.6.0->reflex_ag_grid) (24.1)
# Requirement already satisfied: platformdirs<5.0,>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from reflex>=0.6.0->reflex_ag_grid) (4.3.6)
# Requirement already satisfied: psutil<7.0,>=5.9.4 in /usr/local/lib/python3.10/dist-packages (from reflex>=0.6.0->reflex_ag_grid) (5.9.5)
# Requirement already satisfied: pydantic<3.0,>=1.10.2 in /usr/local/lib/python3.10/dist-packages (from reflex>=0.6.0->reflex_ag_grid) (2.9.2)
# Requirement already satisfied: python-engineio!=4.6.0 in /usr/local/lib/python3.10/dist-packages (from reflex>=0.6.0->reflex_ag_grid) (4.9.1)
# Requirement already satisfied: python-multipart<0.1,>=0.0.5 in /usr/local/lib/python3.10/dist-packages (from reflex>=0.6.0->reflex_ag_grid) (0.0.12)
# Requirement already satisfied: python-socketio<6.0,>=5.7.0 in /usr/local/lib/python3.10/dist-packages (from reflex>=0.6.0->reflex_ag_grid) (5.11.4)
# Requirement already satisfied: redis<6.0,>=4.3.5 in /usr/local/lib/python3.10/dist-packages (from reflex>=0.6.0->reflex_ag_grid) (5.1.1)
# Requirement already satisfied: reflex-chakra>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from reflex>=0.6.0->reflex_ag_grid) (0.6.1)
# Requirement already satisfied: reflex-hosting-cli<2.0,>=0.1.2 in /usr/local/lib/python3.10/dist-packages (from reflex>=0.6.0->reflex_ag_grid) (0.1.13)
# Requirement already satisfied: rich<14.0,>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from reflex>=0.6.0->reflex_ag_grid) (13.9.2)
# Requirement already satisfied: setuptools<70.2,>=69.1.1 in /usr/local/lib/python3.10/dist-packages (from reflex>=0.6.0->reflex_ag_grid) (70.1.1)
# Requirement already satisfied: sqlmodel<0.1,>=0.0.14 in /usr/local/lib/python3.10/dist-packages (from reflex>=0.6.0->reflex_ag_grid) (0.0.22)
# Requirement already satisfied: starlette-admin<1.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from reflex>=0.6.0->reflex_ag_grid) (0.14.1)
# Requirement already satisfied: tomlkit<1.0,>=0.12.4 in /usr/local/lib/python3.10/dist-packages (from reflex>=0.6.0->reflex_ag_grid) (0.13.2)
# Requirement already satisfied: twine<6.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from reflex>=0.6.0->reflex_ag_grid) (5.1.1)
# Requirement already satisfied: typer<1.0,>=0.4.2 in /usr/local/lib/python3.10/dist-packages (from reflex>=0.6.0->reflex_ag_grid) (0.12.5)
# Requirement already satisfied: uvicorn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from reflex>=0.6.0->reflex_ag_grid) (0.31.1)
# Requirement already satisfied: wheel<1.0,>=0.42.0 in /usr/local/lib/python3.10/dist-packages (from reflex>=0.6.0->reflex_ag_grid) (0.44.0)
# Requirement already satisfied: wrapt<2.0,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from reflex>=0.6.0->reflex_ag_grid) (1.16.0)
# Requirement already satisfied: SQLAlchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from alembic<2.0,>=1.11.1->reflex>=0.6.0->reflex_ag_grid) (2.0.35)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic<2.0,>=1.11.1->reflex>=0.6.0->reflex_ag_grid) (1.3.5)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic<2.0,>=1.11.1->reflex>=0.6.0->reflex_ag_grid) (4.12.2)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.10/dist-packages (from build<2.0,>=1.0.3->reflex>=0.6.0->reflex_ag_grid) (1.2.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from build<2.0,>=1.0.3->reflex>=0.6.0->reflex_ag_grid) (2.0.2)
# Requirement already satisfied: starlette<0.39.0,>=0.37.2 in /usr/local/lib/python3.10/dist-packages (from fastapi!=0.111.0,!=0.111.1,>=0.96.0->reflex>=0.6.0->reflex_ag_grid) (0.38.6)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1.0,>=0.25.1->reflex>=0.6.0->reflex_ag_grid) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1.0,>=0.25.1->reflex>=0.6.0->reflex_ag_grid) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1.0,>=0.25.1->reflex>=0.6.0->reflex_ag_grid) (1.0.6)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx<1.0,>=0.25.1->reflex>=0.6.0->reflex_ag_grid) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<1.0,>=0.25.1->reflex>=0.6.0->reflex_ag_grid) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1.0,>=0.25.1->reflex>=0.6.0->reflex_ag_grid) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2<4.0,>=3.1.2->reflex>=0.6.0->reflex_ag_grid) (2.1.5)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0,>=1.10.2->reflex>=0.6.0->reflex_ag_grid) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0,>=1.10.2->reflex>=0.6.0->reflex_ag_grid) (2.23.4)
# Requirement already satisfied: simple-websocket>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from python-engineio!=4.6.0->reflex>=0.6.0->reflex_ag_grid) (1.0.0)
# Requirement already satisfied: bidict>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from python-socketio<6.0,>=5.7.0->reflex>=0.6.0->reflex_ag_grid) (0.23.1)
# Requirement already satisfied: async-timeout>=4.0.3 in /usr/local/lib/python3.10/dist-packages (from redis<6.0,>=4.3.5->reflex>=0.6.0->reflex_ag_grid) (4.0.3)
# Requirement already satisfied: pipdeptree<2.17.0,>=2.13.1 in /usr/local/lib/python3.10/dist-packages (from reflex-hosting-cli<2.0,>=0.1.2->reflex>=0.6.0->reflex_ag_grid) (2.16.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from reflex-hosting-cli<2.0,>=0.1.2->reflex>=0.6.0->reflex_ag_grid) (2.8.2)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from reflex-hosting-cli<2.0,>=0.1.2->reflex>=0.6.0->reflex_ag_grid) (0.9.0)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.10/dist-packages (from reflex-hosting-cli<2.0,>=0.1.2->reflex>=0.6.0->reflex_ag_grid) (13.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0,>=13.0.0->reflex>=0.6.0->reflex_ag_grid) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0,>=13.0.0->reflex>=0.6.0->reflex_ag_grid) (2.18.0)
# Requirement already satisfied: pkginfo>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from twine<6.0,>=4.0.0->reflex>=0.6.0->reflex_ag_grid) (1.10.0)
# Requirement already satisfied: readme-renderer>=35.0 in /usr/local/lib/python3.10/dist-packages (from twine<6.0,>=4.0.0->reflex>=0.6.0->reflex_ag_grid) (44.0)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from twine<6.0,>=4.0.0->reflex>=0.6.0->reflex_ag_grid) (2.32.3)
# Requirement already satisfied: requests-toolbelt!=0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from twine<6.0,>=4.0.0->reflex>=0.6.0->reflex_ag_grid) (1.0.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from twine<6.0,>=4.0.0->reflex>=0.6.0->reflex_ag_grid) (2.2.3)
# Requirement already satisfied: importlib-metadata>=3.6 in /usr/local/lib/python3.10/dist-packages (from twine<6.0,>=4.0.0->reflex>=0.6.0->reflex_ag_grid) (8.4.0)
# Requirement already satisfied: keyring>=15.1 in /usr/lib/python3/dist-packages (from twine<6.0,>=4.0.0->reflex>=0.6.0->reflex_ag_grid) (23.5.0)
# Requirement already satisfied: rfc3986>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from twine<6.0,>=4.0.0->reflex>=0.6.0->reflex_ag_grid) (2.0.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.4.2->reflex>=0.6.0->reflex_ag_grid) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.4.2->reflex>=0.6.0->reflex_ag_grid) (1.5.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=3.6->twine<6.0,>=4.0.0->reflex>=0.6.0->reflex_ag_grid) (3.20.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14.0,>=13.0.0->reflex>=0.6.0->reflex_ag_grid) (0.1.2)
# Requirement already satisfied: pip>=23.1.2 in /usr/local/lib/python3.10/dist-packages (from pipdeptree<2.17.0,>=2.13.1->reflex-hosting-cli<2.0,>=0.1.2->reflex>=0.6.0->reflex_ag_grid) (24.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->reflex-hosting-cli<2.0,>=0.1.2->reflex>=0.6.0->reflex_ag_grid) (1.16.0)
# Requirement already satisfied: nh3>=0.2.14 in /usr/local/lib/python3.10/dist-packages (from readme-renderer>=35.0->twine<6.0,>=4.0.0->reflex>=0.6.0->reflex_ag_grid) (0.2.18)
# Requirement already satisfied: docutils>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from readme-renderer>=35.0->twine<6.0,>=4.0.0->reflex>=0.6.0->reflex_ag_grid) (0.21.2)
# Requirement already satisfied: wsproto in /usr/local/lib/python3.10/dist-packages (from simple-websocket>=0.10.0->python-engineio!=4.6.0->reflex>=0.6.0->reflex_ag_grid) (1.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy>=1.3.0->alembic<2.0,>=1.11.1->reflex>=0.6.0->reflex_ag_grid) (3.1.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1.0,>=0.25.1->reflex>=0.6.0->reflex_ag_grid) (1.2.2)
# Downloading reflex_ag_grid-0.0.7-py3-none-any.whl (7.9 kB)
# Installing collected packages: reflex_ag_grid
# Successfully installed reflex_ag_grid-0.0.7

# %%
import reflex as rx
from reflex_ag_grid import ag_grid
import yfinance as yf
from datetime import datetime, timedelta
import pandas as pd

# %%
import reflex as rx
from reflex_ag_grid import ag_grid
import yfinance as yf
from datetime import datetime, timedelta
import pandas as pd


companies = ["AAPL", "MSFT", "GOOGL", "AMZN", "META"]

class State(rx.State):
    # The selected rows in the AG Grid
    selected_rows: list[dict] = None
    # The currently selected company in AG Grid
    company: str
    # The data fetched from Yahoo Finance
    data: pd.DataFrame
    # The data to be displayed in the AG Grid
    dict_data: list[dict] = [{}]
    # The data to be displayed in the line graph
    dff_ticker_hist: list[dict] = None
    # The datetime of the current fetched data
    datetime_now: datetime = datetime.now()
    # The theme of the AG Grid
    grid_theme: str = "quartz"
    # The list of themes for the AG Grid
    themes: list[str] = ["quartz", "balham", "alpine", "material"]

    def fetch_stock_data(self):
        self.selected_rows = None
        self.datetime_now = datetime.now()
        start_date = self.datetime_now - timedelta(days=180)

        # Fetch data for all tickers in a single download
        self.data = yf.download(companies, start=start_date, end=self.datetime_now, group_by='ticker')
        rows = []
        for ticker in companies:
            # Check if the DataFrame has a multi-level column index (for multiple tickers)
            if isinstance(self.data.columns, pd.MultiIndex):
                ticker_data = self.data[ticker]  # Select the data for the current ticker
            else:
                ticker_data = self.data  # If only one ticker, no multi-level index exists

            for date, row in ticker_data.iterrows():
                rows.append({
                    "ticker": ticker,
                    "date": date.strftime("%Y-%m-%d"),
                    "open": round(row["Open"], 2),
                    "high": round(row["High"], 2),
                    "mid": round((row["High"] + row["Low"]) / 2, 2),
                    "low": round(row["Low"], 2),
                    "close": round(row["Close"], 2),
                    "volume": int(row["Volume"]),
                })

        self.dict_data = sorted(rows, key=lambda x: (x["date"], x["ticker"]), reverse=True)



    def handle_selection(self, selected_rows, _, __):
        self.selected_rows = selected_rows
        self.update_line_graph()

    def update_line_graph(self):
        if self.selected_rows:
            ticker = self.selected_rows[0]["ticker"]
        else:
            self.dff_ticker_hist = None
            return
        self.company = ticker

        dff_ticker_hist = self.data[ticker].reset_index()
        dff_ticker_hist["Date"] = pd.to_datetime(dff_ticker_hist["Date"]).dt.strftime("%Y-%m-%d")

        dff_ticker_hist["Mid"] = (dff_ticker_hist["Open"] + dff_ticker_hist["Close"]) / 2
        dff_ticker_hist["DayDifference"] = dff_ticker_hist.apply(
            lambda row: [row["High"] - row["Mid"], row["Mid"] - row["Low"]], axis=1
        )

        self.dff_ticker_hist = dff_ticker_hist.to_dict(orient="records")


column_defs = [
    ag_grid.column_def(field="ticker", header_name="Ticker", filter=ag_grid.filters.text, checkbox_selection=True),
    ag_grid.column_def(field="date", header_name="Date", filter=ag_grid.filters.date),
    ag_grid.column_def(field="open", header_name="Open", filter=ag_grid.filters.number),
    ag_grid.column_def(field="high", header_name="High", filter=ag_grid.filters.number),
    ag_grid.column_def(field="low", header_name="Low", filter=ag_grid.filters.number),
    ag_grid.column_def(field="close", header_name="Close", filter=ag_grid.filters.number),
    ag_grid.column_def(field="volume", header_name="Volume", filter=ag_grid.filters.number),
]


def index():
    return rx.vstack(
        rx.hstack(
            rx.heading("Stock Market Data with AG Grid in Reflex", font_size="2em"),
            rx.spacer(),
            rx.color_mode.button(),
            margin_y="1em",
            width="100%",
        ),
        rx.hstack(
            rx.button(
                "Fetch Latest Data",
                on_click=State.fetch_stock_data,
                margin_bottom="1em",
            ),
            rx.badge(rx.moment(State.datetime_now), size="3"),
        ),
        rx.hstack(
            rx.text("Grid Theme:"),
            rx.select(
                State.themes,
                value=State.grid_theme,
                on_change=State.set_grid_theme,
                size="1",
            ),
            rx.text("(Click on a row to see the past 6 months of data for that company)"),
        ),
        rx.cond(
            State.dff_ticker_hist,
            rx.vstack(
                rx.heading(State.company),
                rx.recharts.line_chart(
                    rx.recharts.line(
                        rx.recharts.error_bar(
                            data_key="DayDifference",
                            direction="y",
                            width=4,
                            stroke_width=2,
                            stroke="red",
                        ),
                        data_key="Mid",
                    ),
                    rx.recharts.x_axis(data_key="Date"),
                    rx.recharts.y_axis(domain=["auto", "auto"]),
                    data=State.dff_ticker_hist,
                    width="100%",
                    height=300,
                ),
                align_items="center",
                width="100%",
            ),
        ),
        ag_grid(
            id="myAgGrid",
            column_defs=column_defs,
            row_data=State.dict_data,
            pagination=True,
            pagination_page_size=20,
            pagination_page_size_selector=[10, 20, 50, 100],
            on_selection_changed=State.handle_selection,
            theme=State.grid_theme,
            width="100%",
            height="60vh",
        ),
        width="80%",
        margin="0 auto",
        spacing="4",
    )


# Add state and page to the app.
app = rx.App()
app.add_page(index)
