# %% [markdown]
# [Reference](https://hmix13.medium.com/leaflet-your-data-speak-creating-interactive-maps-with-folium-in-python-8c975b4a4771)

# %%
pip install folium
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import folium

# Create a map object
m = folium.Map(location=[28.583014, 77.257322], zoom_start=13)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium

# Create a map object
m = folium.Map(location=[28.583014, 77.257322], zoom_start=13)

# Add a marker to the map
folium.Marker(location=[28.593121, 77.250720], popup='Portland').add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium

# Create a map object
m = folium.Map(location=[45.5236, -122.6750], zoom_start=4)

# Create a GeoJSON object with features for each state
geojson = {
  "type": "FeatureCollection",
  "features": [
    {
      "type": "Feature",
      "properties": {"name": "Oregon"},
      "geometry": {
        "type": "Polygon",
        "coordinates": [
          [
            [-117.38983154296874, 42.99381037570381],
            [-117.04071044921874, 43.08801511965121],
            [-116.9561767578125, 42.83883094750151],
            [-117.20764160156249, 42.59785561797415],
            [-117.38983154296874, 42.99381037570381]
          ]
        ]
      }
    },
    {
      "type": "Feature",
      "properties": {"name": "California"},
      "geometry": {
        "type": "Polygon",
        "coordinates": [
          [
            [-124.566650390625, 41.99105688270877],
            [-124.48211669921874, 42.09430373622162],
            [-124.085693359375, 41.99827980119132],
            [-124.02252197265625, 41.74139909269676],
            [-124.48822021484375, 41.59858822666668],
            [-124.51141357421875, 41.92951468066458],
            [-124.566650390625, 41.99105688270877]
          ]
        ]
      }
    },
    {
      "type": "Feature",
      "properties": {"name": "Washington"},
      "geometry": {
        "type": "Polygon",
        "coordinates": [
          [
            [-123.31787109375, 47.58882162866207],
            [-123.013916015625, 47.70225182744022],
            [-122.685546875, 47.36236101261093],
            [-122.7740478515625, 47.21199870672052],
            [-123.038330078125, 47.24940695788816],
            [-123.31787109375, 47.58882162866207]
          ]
        ]
      }
    },
    {
      "type": "Feature",
      "properties": {"name": "Nevada"},
      "geometry": {
        "type": "Polygon",
        "coordinates": [
          [
            [-119.20654296874999, 38.19715703629668],
            [-118.85498046875, 38.335182426490015],
            [-118.524169921875, 38.007394957853666],
            [-118.84033203125, 37.799350170523925],
            [-119.20654296874999, 38.19715703629668]
          ]
        ]
      }
    }
  ]
}

# Create a choropleth layer for the map
folium.Choropleth(
    geo_data=geojson,
    fill_color='YlGn',
    fill_opacity=0.7,
    line_opacity=0.2,
).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
