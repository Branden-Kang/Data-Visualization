# %% [markdown]
# [Reference](https://towardsdatascience.com/visualizing-routes-on-interactive-maps-with-python-part-1-44f8d25d0761)

# %%
# !pip insall geopy folium
# Out:
# ERROR: unknown command "insall" - maybe you meant "install"

# %%
from typing import Tuple, List, Dict

import pandas as pd
import folium

pd.set_option('display.precision', 2)


df_sites = pd.DataFrame(
    [['hotel',              48.8527, 2.3542],
     ['Sacre Coeur',        48.8867, 2.3431],
     ['Louvre',             48.8607, 2.3376],
     ['Montmartre',         48.8872, 2.3388],
     ['Port de Suffren',    48.8577, 2.2902],
     ['Arc de Triomphe',    48.8739, 2.2950],
     ['Av. Champs Élysées', 48.8710, 2.3036],
     ['Notre Dame',         48.8531, 2.3498],
     ['Tour Eiffel',        48.8585, 2.2945]],
    columns=pd.Index(['site', 'latitude', 'longitude'], name='paris')
)

df_sites
# Out:
# paris                site  latitude  longitude
# 0                   hotel     48.85       2.35
# 1             Sacre Coeur     48.89       2.34
# 2                  Louvre     48.86       2.34
# 3              Montmartre     48.89       2.34
# 4         Port de Suffren     48.86       2.29
# 5         Arc de Triomphe     48.87       2.29
# 6      Av. Champs Élysées     48.87       2.30
# 7              Notre Dame     48.85       2.35
# 8             Tour Eiffel     48.86       2.29

# %%
avg_location = df_sites[['latitude', 'longitude']].mean()
map_paris = folium.Map(location=avg_location, zoom_start=13)

# %%
for site in df_sites.itertuples():
    marker = folium.Marker(location=(site.latitude, site.longitude),
                           tooltip=site.site)
    marker.add_to(map_paris)

map_paris
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bac1fbadf7c6090a5f875d5332d6f406 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bac1fbadf7c6090a5f875d5332d6f406&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bac1fbadf7c6090a5f875d5332d6f406 = L.map(
#                 &quot;map_bac1fbadf7c6090a5f875d5332d6f406&quot;,
#                 {
#                     center: [48.86683333333333, 2.3229777777777776],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e35888cbdf8b970a906f77d081969f52 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bac1fbadf7c6090a5f875d5332d6f406);
#
#
#             var marker_3e23ce5de98fa0e767ccc1d6320b1624 = L.marker(
#                 [48.8527, 2.3542],
#                 {}
#             ).addTo(map_bac1fbadf7c6090a5f875d5332d6f406);
#
#
#             marker_3e23ce5de98fa0e767ccc1d6320b1624.bindTooltip(
#                 `&lt;div&gt;
#                      hotel
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c9e644d92c779f38ce21858fa801b58a = L.marker(
#                 [48.8867, 2.3431],
#                 {}
#             ).addTo(map_bac1fbadf7c6090a5f875d5332d6f406);
#
#
#             marker_c9e644d92c779f38ce21858fa801b58a.bindTooltip(
#                 `&lt;div&gt;
#                      Sacre Coeur
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_41c33717de487dc3d2ba4453c10a159b = L.marker(
#                 [48.8607, 2.3376],
#                 {}
#             ).addTo(map_bac1fbadf7c6090a5f875d5332d6f406);
#
#
#             marker_41c33717de487dc3d2ba4453c10a159b.bindTooltip(
#                 `&lt;div&gt;
#                      Louvre
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_94256922e5f227f055654acb1f191723 = L.marker(
#                 [48.8872, 2.3388],
#                 {}
#             ).addTo(map_bac1fbadf7c6090a5f875d5332d6f406);
#
#
#             marker_94256922e5f227f055654acb1f191723.bindTooltip(
#                 `&lt;div&gt;
#                      Montmartre
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c94da382d6f242e203facd1a1d2eadb0 = L.marker(
#                 [48.8577, 2.2902],
#                 {}
#             ).addTo(map_bac1fbadf7c6090a5f875d5332d6f406);
#
#
#             marker_c94da382d6f242e203facd1a1d2eadb0.bindTooltip(
#                 `&lt;div&gt;
#                      Port de Suffren
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6f85470eb60d961fdb8937b8855a159c = L.marker(
#                 [48.8739, 2.295],
#                 {}
#             ).addTo(map_bac1fbadf7c6090a5f875d5332d6f406);
#
#
#             marker_6f85470eb60d961fdb8937b8855a159c.bindTooltip(
#                 `&lt;div&gt;
#                      Arc de Triomphe
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_36e4aaacddec1594bdfa097ce47e48a1 = L.marker(
#                 [48.871, 2.3036],
#                 {}
#             ).addTo(map_bac1fbadf7c6090a5f875d5332d6f406);
#
#
#             marker_36e4aaacddec1594bdfa097ce47e48a1.bindTooltip(
#                 `&lt;div&gt;
#                      Av. Champs Élysées
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_405f803ad5ee135fb067f0c03afd696a = L.marker(
#                 [48.8531, 2.3498],
#                 {}
#             ).addTo(map_bac1fbadf7c6090a5f875d5332d6f406);
#
#
#             marker_405f803ad5ee135fb067f0c03afd696a.bindTooltip(
#                 `&lt;div&gt;
#                      Notre Dame
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3716f1089ac33cc6e47beee1183c1187 = L.marker(
#                 [48.8585, 2.2945],
#                 {}
#             ).addTo(map_bac1fbadf7c6090a5f875d5332d6f406);
#
#
#             marker_3716f1089ac33cc6e47beee1183c1187.bindTooltip(
#                 `&lt;div&gt;
#                      Tour Eiffel
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_route = df_sites.copy()
df_route.index.name = 'visit_order'

df_route
# Out:
# paris                      site  latitude  longitude
# visit_order
# 0                         hotel     48.85       2.35
# 1                   Sacre Coeur     48.89       2.34
# 2                        Louvre     48.86       2.34
# 3                    Montmartre     48.89       2.34
# 4               Port de Suffren     48.86       2.29
# 5               Arc de Triomphe     48.87       2.29
# 6            Av. Champs Élysées     48.87       2.30
# 7                    Notre Dame     48.85       2.35
# 8                   Tour Eiffel     48.86       2.29

# %%
df_route_segments = df_route.join(
    df_route.shift(-1),  # map each stop to its next stop
    rsuffix='_next'
).dropna()  # last stop has no "next one", so drop it

df_route_segments
# Out:
# paris                      site  latitude  longitude           site_next  \
# visit_order
# 0                         hotel     48.85       2.35         Sacre Coeur
# 1                   Sacre Coeur     48.89       2.34              Louvre
# 2                        Louvre     48.86       2.34          Montmartre
# 3                    Montmartre     48.89       2.34     Port de Suffren
# 4               Port de Suffren     48.86       2.29     Arc de Triomphe
# 5               Arc de Triomphe     48.87       2.29  Av. Champs Élysées
# 6            Av. Champs Élysées     48.87       2.30          Notre Dame
# 7                    Notre Dame     48.85       2.35         Tour Eiffel
#
# paris        latitude_next  longitude_next
# visit_order
# 0                    48.89            2.34
# 1                    48.86            2.34
# 2                    48.89            2.34
# 3                    48.86            2.29
# 4                    48.87            2.29
# 5                    48.87            2.30
# 6                    48.85            2.35
# 7                    48.86            2.29

# %%
map_paris = folium.Map(location=avg_location, zoom_start=13)

for stop in df_route_segments.itertuples():
    # marker for current stop
    marker = folium.Marker(location=(stop.latitude, stop.longitude),
                           tooltip=stop.site)
    # line for the route segment connecting current to next stop
    line = folium.PolyLine(
        locations=[(stop.latitude, stop.longitude),
                   (stop.latitude_next, stop.longitude_next)],
        tooltip=f"{stop.site} to {stop.site_next}",
    )
    # add elements to the map
    marker.add_to(map_paris)
    line.add_to(map_paris)

# maker for last stop wasn't added in for loop, so adding it now
folium.Marker(location=(stop.latitude_next, stop.longitude_next),
              tooltip=stop.site_next).add_to(map_paris);

map_paris
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0254ec14809b2965b4dd63d797c7e059 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0254ec14809b2965b4dd63d797c7e059&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0254ec14809b2965b4dd63d797c7e059 = L.map(
#                 &quot;map_0254ec14809b2965b4dd63d797c7e059&quot;,
#                 {
#                     center: [48.86683333333333, 2.3229777777777776],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c6b5f81786537d5188f24109d89011e1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0254ec14809b2965b4dd63d797c7e059);
#
#
#             var marker_6af186ee6ba8a747da7d9067b1716632 = L.marker(
#                 [48.8527, 2.3542],
#                 {}
#             ).addTo(map_0254ec14809b2965b4dd63d797c7e059);
#
#
#             marker_6af186ee6ba8a747da7d9067b1716632.bindTooltip(
#                 `&lt;div&gt;
#                      hotel
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_33e1d1b4a87035d1c1330af652a40616 = L.polyline(
#                 [[48.8527, 2.3542], [48.8867, 2.3431]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0254ec14809b2965b4dd63d797c7e059);
#
#
#             poly_line_33e1d1b4a87035d1c1330af652a40616.bindTooltip(
#                 `&lt;div&gt;
#                      hotel to Sacre Coeur
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c27fe82308ff973d39023128c0147cfd = L.marker(
#                 [48.8867, 2.3431],
#                 {}
#             ).addTo(map_0254ec14809b2965b4dd63d797c7e059);
#
#
#             marker_c27fe82308ff973d39023128c0147cfd.bindTooltip(
#                 `&lt;div&gt;
#                      Sacre Coeur
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_89ec741bed38eb4f968af0cfad77f9cd = L.polyline(
#                 [[48.8867, 2.3431], [48.8607, 2.3376]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0254ec14809b2965b4dd63d797c7e059);
#
#
#             poly_line_89ec741bed38eb4f968af0cfad77f9cd.bindTooltip(
#                 `&lt;div&gt;
#                      Sacre Coeur to Louvre
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e6dd7e6446d89c109d3d6820df200629 = L.marker(
#                 [48.8607, 2.3376],
#                 {}
#             ).addTo(map_0254ec14809b2965b4dd63d797c7e059);
#
#
#             marker_e6dd7e6446d89c109d3d6820df200629.bindTooltip(
#                 `&lt;div&gt;
#                      Louvre
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_f5db937289d57c1e89271605493530a2 = L.polyline(
#                 [[48.8607, 2.3376], [48.8872, 2.3388]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0254ec14809b2965b4dd63d797c7e059);
#
#
#             poly_line_f5db937289d57c1e89271605493530a2.bindTooltip(
#                 `&lt;div&gt;
#                      Louvre to Montmartre
#                  &lt;/div&gt;`,

# %%
map_paris = folium.Map(location=avg_location, zoom_start=13)

for stop in df_route_segments.itertuples():
    initial_stop = stop.Index == 0
    # icon for current stop
    icon = folium.Icon(icon='home' if initial_stop else 'info-sign',
                       color='cadetblue' if initial_stop else 'red')
    # marker for current stop
    marker = folium.Marker(location=(stop.latitude, stop.longitude),
                           icon=icon, tooltip=stop.site)
    # line for the route segment connecting current to next stop
    line = folium.PolyLine(
        locations=[(stop.latitude, stop.longitude),
                   (stop.latitude_next, stop.longitude_next)],
        tooltip=f"{stop.site} to {stop.site_next}",
    )
    # add elements to the map
    marker.add_to(map_paris)
    line.add_to(map_paris)

# When for loop ends, the stop variable has the second-to-last
# stop in the route, so the marker for the last stop is missing
# We add it now using the "next" columns of the last row
folium.Marker(
    location=(stop.latitude_next, stop.longitude_next),
    tooltip=stop.site_next,
    icon = folium.Icon(icon='info-sign', color='red')
).add_to(map_paris);

map_paris  # show map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_54bcfe2cc9493c3bc048b1df8f2a8e6c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_54bcfe2cc9493c3bc048b1df8f2a8e6c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_54bcfe2cc9493c3bc048b1df8f2a8e6c = L.map(
#                 &quot;map_54bcfe2cc9493c3bc048b1df8f2a8e6c&quot;,
#                 {
#                     center: [48.86683333333333, 2.3229777777777776],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0f08c8056cb357c4637595949a0f86d4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_54bcfe2cc9493c3bc048b1df8f2a8e6c);
#
#
#             var marker_730d94a093177186c05af31e7d8c42ce = L.marker(
#                 [48.8527, 2.3542],
#                 {}
#             ).addTo(map_54bcfe2cc9493c3bc048b1df8f2a8e6c);
#
#
#             var icon_ea659e64e411a164e92e327caba8d3c8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_730d94a093177186c05af31e7d8c42ce.setIcon(icon_ea659e64e411a164e92e327caba8d3c8);
#
#
#             marker_730d94a093177186c05af31e7d8c42ce.bindTooltip(
#                 `&lt;div&gt;
#                      hotel
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_83193d6bc3d2df333f8b26696ce7038c = L.polyline(
#                 [[48.8527, 2.3542], [48.8867, 2.3431]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_54bcfe2cc9493c3bc048b1df8f2a8e6c);
#
#
#             poly_line_83193d6bc3d2df333f8b26696ce7038c.bindTooltip(
#                 `&lt;div&gt;
#                      hotel to Sacre Coeur
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4fdad7334559d412bcfb7834256de55f = L.marker(
#                 [48.8867, 2.3431],
#                 {}
#             ).addTo(map_54bcfe2cc9493c3bc048b1df8f2a8e6c);
#
#
#             var icon_8c222993aeae402b5deae92be7e2e6fd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4fdad7334559d412bcfb7834256de55f.setIcon(icon_8c222993aeae402b5deae92be7e2e6fd);
#
#
#             marker_4fdad7334559d412bcfb7834256de55f.bindTooltip(
#                 `&lt;div&gt;
#                      Sacre Coeur
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_7a1e30ac1822137404290acd5d219985 = L.polyline(
#                 [[48.8867, 2.3431], [48.8607, 2.3376]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_54bcfe2cc9493c3bc048b1df8f2a8e6c);
#
#
#             poly_line_7a1e30ac1822137404290acd5d219985.bindTooltip(
#                 `&lt;div&gt;
#                      Sacre Coeur to Louvre
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_68c552713d4feeb3b741ac4b800c82a5 = L.marker(
#                 [48.8607, 2.3376],
#                 {}
#             ).addTo(map_54bcfe2cc9493c3bc048b1df8f2a8e6c);
#
#
#             var icon_4222925415b372a44429f8483c6abfb5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&q

# %%
from geopy.distance import geodesic

_Location = Tuple[float, float]


def ellipsoidal_distance(point1: _Location, point2: _Location) -> float:
    """Calculate ellipsoidal distance (in meters) between point1 and
    point2 where each point is represented as a tuple (lat, lon)"""
    return geodesic(point1, point2).meters

# %%
df_route_segments['distance_seg'] = df_route_segments.apply(
    lambda stop: ellipsoidal_distance(
        (stop.latitude, stop.longitude),
        (stop.latitude_next, stop.longitude_next)),
    axis=1
)

df_route_segments
# Out:
# paris                      site  latitude  longitude           site_next  \
# visit_order
# 0                         hotel     48.85       2.35         Sacre Coeur
# 1                   Sacre Coeur     48.89       2.34              Louvre
# 2                        Louvre     48.86       2.34          Montmartre
# 3                    Montmartre     48.89       2.34     Port de Suffren
# 4               Port de Suffren     48.86       2.29     Arc de Triomphe
# 5               Arc de Triomphe     48.87       2.29  Av. Champs Élysées
# 6            Av. Champs Élysées     48.87       2.30          Notre Dame
# 7                    Notre Dame     48.85       2.35         Tour Eiffel
#
# paris        latitude_next  longitude_next  distance_seg
# visit_order
# 0                    48.89            2.34       3867.74
# 1                    48.86            2.34       2919.40
# 2                    48.89            2.34       2948.31
# 3                    48.86            2.29       4844.92
# 4                    48.87            2.29       1835.65
# 5                    48.87            2.30        708.53
# 6                    48.85            2.35       3931.12
# 7                    48.86            2.29       4102.26

# %%
map_paris = folium.Map(location=avg_location, zoom_start=13)

for stop in df_route_segments.itertuples():
    initial_stop = stop.Index == 0
    # marker for current stop
    icon = folium.Icon(icon='home' if initial_stop else 'info-sign',
                       color='cadetblue' if initial_stop else 'red')
    marker = folium.Marker(
        location=(stop.latitude, stop.longitude),
        icon=icon,
        # display the name and stop number at each site's marker
        tooltip=f"<b>Name</b>: {stop.site} <br>" \
              + f"<b>Stop number</b>: {stop.Index} <br>"
    )
    # line for the route segment connecting current to next stop
    line = folium.PolyLine(
        locations=[(stop.latitude, stop.longitude),
                   (stop.latitude_next, stop.longitude_next)],
        # display the start, end, and distance of each segment
        tooltip=f"<b>From</b>: {stop.site} <br>" \
              + f"<b>To</b>: {stop.site_next} <br>" \
              + f"<b>Distance</b>: {stop.distance_seg:.0f} m",
    )
    # add elements to the map
    marker.add_to(map_paris)
    line.add_to(map_paris)

# add route's last marker, as it wasn't included in for loop
folium.Marker(
    location=(stop.latitude_next, stop.longitude_next),
    tooltip=f"<b>Name</b>: {stop.site_next} <br>" \
          + f"<b>Stop number</b>: {stop.Index + 1} <br>",
    icon = folium.Icon(icon='info-sign', color='red')
).add_to(map_paris);

map_paris  # show map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0fd5cc284ec8160d6461d112e09d7b79 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0fd5cc284ec8160d6461d112e09d7b79&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0fd5cc284ec8160d6461d112e09d7b79 = L.map(
#                 &quot;map_0fd5cc284ec8160d6461d112e09d7b79&quot;,
#                 {
#                     center: [48.86683333333333, 2.3229777777777776],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a1e30ed078003e2929f9759c960dd5e6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0fd5cc284ec8160d6461d112e09d7b79);
#
#
#             var marker_fa62ff96f0e8f467933c7807ff04ab2c = L.marker(
#                 [48.8527, 2.3542],
#                 {}
#             ).addTo(map_0fd5cc284ec8160d6461d112e09d7b79);
#
#
#             var icon_816953fc36d144d31f2ec6a02bc77b00 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fa62ff96f0e8f467933c7807ff04ab2c.setIcon(icon_816953fc36d144d31f2ec6a02bc77b00);
#
#
#             marker_fa62ff96f0e8f467933c7807ff04ab2c.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;Name&lt;/b&gt;: hotel &lt;br&gt;&lt;b&gt;Stop number&lt;/b&gt;: 0 &lt;br&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_30c5570607bee61074a22712ff5ff97e = L.polyline(
#                 [[48.8527, 2.3542], [48.8867, 2.3431]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0fd5cc284ec8160d6461d112e09d7b79);
#
#
#             poly_line_30c5570607bee61074a22712ff5ff97e.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;From&lt;/b&gt;: hotel &lt;br&gt;&lt;b&gt;To&lt;/b&gt;: Sacre Coeur &lt;br&gt;&lt;b&gt;Distance&lt;/b&gt;: 3868 m
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_391100e8678ed9e9e8543301bb75b052 = L.marker(
#                 [48.8867, 2.3431],
#                 {}
#             ).addTo(map_0fd5cc284ec8160d6461d112e09d7b79);
#
#
#             var icon_9dd9c3bb47b7f474af2e9fec2d9dcb40 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_391100e8678ed9e9e8543301bb75b052.setIcon(icon_9dd9c3bb47b7f474af2e9fec2d9dcb40);
#
#
#             marker_391100e8678ed9e9e8543301bb75b052.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;Name&lt;/b&gt;: Sacre Coeur &lt;br&gt;&lt;b&gt;Stop number&lt;/b&gt;: 1 &lt;br&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_81ff0cbe81112374cdb4f65e97c935c1 = L.polyline(
#                 [[48.8867, 2.3431], [48.8607, 2.3376]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0fd5cc284ec8160d6461d112e09d7b79);
#
#
#             poly_line_81ff0cbe81112374cdb4f65e97c935c1.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;From&lt;/b&gt;: Sacre Coeur &lt;br&gt;&lt;b&gt;To&lt;/b&gt;: Louvre &lt;br&gt;&lt;b&gt;Distance&lt;/b&gt;: 2919 m
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_32bf049aaa09b07700fa5ef0d45df391 =

# %%
def _make_route_segments_df(df_route: pd.DataFrame) -> pd.DataFrame:
    """Given a dataframe whose rows are ordered stops in a route,
    and where the index has integers representing the visit order of those
    stops, return a dataframe having new columns with the information of
    each stop's next site"""
    df_route_segments = df_route.join(
        df_route.shift(-1),  # map each stop to its next
        rsuffix='_next').dropna()

    df_route_segments['distance_seg'] = df_route_segments.apply(
        lambda stop: ellipsoidal_distance(
            (stop.latitude, stop.longitude),
            (stop.latitude_next, stop.longitude_next)
        ), axis=1
    )
    return df_route_segments


def plot_route_on_map(df_route: pd.DataFrame) -> folium.Map:
    """Takes a dataframe of a route and displays it on a map, adding
    a marker for each stop and a line for each pair of consecutive
    stops"""
    df_route_segments = _make_route_segments_df(df_route)

    # create empty map
    avg_location = df_route[['latitude', 'longitude']].mean()
    map_route = folium.Map(location=avg_location, zoom_start=13)

    for stop in df_route_segments.itertuples():
        initial_stop = stop.Index == 0
        # marker for current stop
        icon = folium.Icon(icon='home' if initial_stop else 'info-sign',
                           color='cadetblue' if initial_stop else 'red')
        marker = folium.Marker(
            location=(stop.latitude, stop.longitude),
            icon=icon,
            tooltip=f"<b>Name</b>: {stop.site} <br>" \
                  + f"<b>Stop number</b>: {stop.Index} <br>"
        )
        # line for the route segment connecting current to next stop
        line = folium.PolyLine(
            locations=[(stop.latitude, stop.longitude),
                       (stop.latitude_next, stop.longitude_next)],
            # add to each line its start, end, and distance
            tooltip=f"<b>From</b>: {stop.site} <br>" \
                  + f"<b>To</b>: {stop.site_next} <br>" \
                  + f"<b>Distance</b>: {stop.distance_seg:.0f} m",
        )
        # add elements to the map
        marker.add_to(map_route)
        line.add_to(map_route)

    # When for loop ends, the stop variable has the second-to-last stop in
    # the route, so the marker for the last stop is missing, and we add it
    # now using the "next" columns of the last row
    folium.Marker(
        location=(stop.latitude_next, stop.longitude_next),
        tooltip=f"<b>Name</b>: {stop.site_next} <br>" \
              + f"<b>Stop number</b>: {stop.Index + 1} <br>",
        icon = folium.Icon(icon='info-sign', color='red')
    ).add_to(map_route)

    return map_route

# %%
df_route_closed = pd.concat(
   [df_route, df_route.head(1)], ignore_index=True
)
df_route_closed.index.name = df_route.index.name

df_route_closed
# Out:
# paris                      site  latitude  longitude
# visit_order
# 0                         hotel     48.85       2.35
# 1                   Sacre Coeur     48.89       2.34
# 2                        Louvre     48.86       2.34
# 3                    Montmartre     48.89       2.34
# 4               Port de Suffren     48.86       2.29
# 5               Arc de Triomphe     48.87       2.29
# 6            Av. Champs Élysées     48.87       2.30
# 7                    Notre Dame     48.85       2.35
# 8                   Tour Eiffel     48.86       2.29
# 9                         hotel     48.85       2.35
