# %% [markdown]
# [Reference](https://levelup.gitconnected.com/discover-the-python-powerhouse-10-libraries-that-take-data-visualization-to-new-heights-8d7664372d02)

# %% [markdown]
# # 1. Plotly: Interactive Visualizations Like Never Before

# %%
# import plotly.express as px

# data = {'Category': ['A', 'B', 'C'], 'Value': [10, 15, 7]}
# df = pd.DataFrame(data)
# fig = px.bar(df, x='Category', y='Value')
# fig.show()

# %% [markdown]
# # 2. Seaborn: Beauty and Simplicity Combined

# %%
import seaborn as sns

tips = sns.load_dataset('tips')
sns.boxplot(x='day', y='total_bill', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # 3. Matplotlib: The Classic Choice for Versatile Visualizations

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 8, 6, 4, 2]
plt.plot(x, y)
plt.show()

# %% [markdown]
# # 4. Altair: Declarative Visualization in a Snap

# %%
import altair as alt
from vega_datasets import data

cars = data.cars()
alt.Chart(cars).mark_circle().encode(
    x='Horsepower',
    y='Miles_per_Gallon',
    color='Origin'
).interactive()
# Out:
# alt.Chart(...)

# %% [markdown]
# # 5. Bokeh: Interactive Visualizations for the Web

# %%
from bokeh.plotting import figure, show
from bokeh.models import HoverTool
from bokeh.sampledata.iris import flowers

p = figure(title='Iris Dataset', x_axis_label='Petal Length', y_axis_label='Petal Width')
p.add_tools(HoverTool(tooltips=[('Species', '@species'), ('Sepal Width', '@sepal_width')]))
p.circle(x='petal_length', y='petal_width', size=8, source=flowers)
show(p)

# %% [markdown]
# # 6. ggplot: Harnessing the Power of R’s ggplot2

# %%
# from ggplot import *

# df = pd.DataFrame({'x': [1, 2, 3, 4, 5], 'y': [10, 8, 6, 4, 2]})
# ggplot(aes(x='x', y='y'), data=df) + geom_point()

# %% [markdown]
# # 7. NetworkX: Visualizing Complex Networks

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.karate_club_graph()
nx.draw(G, with_labels=True)
plt.show()

# %% [markdown]
# # 8. Wordcloud: Unleash the Power of Text Visualization

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = "Lorem ipsum dolor sit amet, consectetur adipiscing elit."
wordcloud = WordCloud().generate(text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# # 9. Pygal: Interactive SVG Charts

# %%
# !pip install pygal
# Out:
# Collecting pygal
#   Downloading pygal-3.0.0-py2.py3-none-any.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 kB 9.1 MB/s eta 0:00:00
# Installing collected packages: pygal
# Successfully installed pygal-3.0.0

# %%
import pygal

bar_chart = pygal.Bar()
bar_chart.add('Series', [1, 3, 2, 5, 4])
bar_chart.render()
# Out:
# b'<?xml version=\'1.0\' encoding=\'utf-8\'?>\n<svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-da3c4142-5f5f-4245-94f4-c33bdda2144b" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 3.0.0 (lxml) \xc2\xa9Kozea 2012-2016 on 2023-07-01--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-da3c4142-5f5f-4245-94f4-c33bdda2144b{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-da3c4142-5f5f-4245-94f4-c33bdda2144b .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-da3c4142-5f5f-4245-94f4-c33bdda2144b .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-da3c4142-5f5f-4245-94f4-c33bdda2144b .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-da3c4142-5f5f-4245-94f4-c33bdda2144b .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-da3c4142-5f5f-4245-94f4-c33bdda2144b .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-da3c4142-5f5f-4245-94f4-c33bdda2144b .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-da3c4142-5f5f-4245-94f4-c33bdda2144b .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-da3c4142-5f5f-4245-94f4-c33bdda2144b text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}\n#chart-da3c4142-5f5f-4245-94f4-c33bdda2144b{background-color:rgba(249,249,249,1)}#chart-da3c4142-5f5f-4245-94f4-c33bdda2144b path,#chart-da3c4142-5f5f-4245-94f4-c33bdda2144b line,#chart-da3c4142-5f5f-4245-94f4-c33bdda2144b rect,#chart-da3c4142-5f5f-4245-94f4-c33bdda2144b circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-da3c4142-5f5f-4245-94f4-c33bdda2144b .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-da3c4142-5f5f-4245-94f4-c33bdda2144b .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-da3c4142-5f5f-4245-94f4-c33bdda2144b .graph{fill:rgba(0,0,0,.87)}#chart-da3c4142-5f5f-4245-94f4-c33bdda2144b text.no_data{fill:rgba(0,0,0,1)}#chart-da3c4142-5f5f-4245-94f4-c33bdda2144b .title{fill:rgba(0,0,0,1)}#chart-da3c4142-5f5f-4245-94f4-c33bdda2144b .legends .legend text{fill:rgba(0,0,0,.87)}#chart-da3c4142-5f5f-4245-94f4-c33bdda2144b .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-da3c4142-5f5f-4245-94f4-c33bdda2144b .axis .line{stroke:rgba(0,0,0,1)}#chart-da3c4142-5f5f-4245-94f4-c33bdda2144b .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-da3c4142-5f5f-4245-94f4-c33bdda2144b .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-da3c4142-5f5f-4245-94f4-c33bdda2144b .axis text.major{fill:rgba(0,0,0,1)}#chart-da3c4142-5f5f-4245-94f4-c33bdda2144b .axis.y .guides:hover .guide.line,#chart-da3c4142-5f5f-4245-94f4-c33bdda2144b .line-graph .axis.x .guides:hover .guide.line,#chart-da3c4142-5f5f-4245-94f4-c33bdda2144b .stackedline-graph .axis.x .guides:hover .guide.line,#chart-da3c4142-5f5f-4245-94f4-c33bdda2144b .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-da3c4142-5f5f-4245-94f4-c33bdda2144b .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-da3c4142-5f5f-4245-94f4-c33bdda2144b .reactive{fill-opacity:.7;stroke-opacity:.8;stroke-width:1}#chart-da3c4142-5f5f-4245-94f4-c33bdda2144b .ci{stroke:rgba(0,0,0,.87)}#chart-da3c4142-5f5f-4245-94f4-c33bdda2144b .reactive.active,#chart-da3c4142-5f5f-4245-94f4-c33bdda2144b .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-da3c4142-5f5f-4245-94f4-c33bdda2144b .ci .reactive.active{stroke-width:1.5}#chart-da3c4142-5f5f-4245-94f4-c33bdda2144b .series text{fill:rgba(0,0,0,1)}#chart-da3c4142-5f5f-4245-94f4-c33bdda2144b .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:o ...

# %% [markdown]
# # 10. Folium: Maps Made Easy

# %%
import folium

m = folium.Map(location=[37.7749, -122.4194], zoom_start=12)
folium.Marker(location=[37.7749, -122.4194], popup='San Francisco').add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5f499634454b5e88968e2bb0e22e4c8e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5f499634454b5e88968e2bb0e22e4c8e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5f499634454b5e88968e2bb0e22e4c8e = L.map(
#                 &quot;map_5f499634454b5e88968e2bb0e22e4c8e&quot;,
#                 {
#                     center: [37.7749, -122.4194],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e1b12c9d9502171cdde71d12fe3cbb51 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5f499634454b5e88968e2bb0e22e4c8e);
#
#
#             var marker_bccb0f070479d0755433e81edefde36c = L.marker(
#                 [37.7749, -122.4194],
#                 {}
#             ).addTo(map_5f499634454b5e88968e2bb0e22e4c8e);
#
#
#         var popup_9881b63a7d14793784664057c3d02149 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f329d624075ca58041e387489bf32932 = $(`&lt;div id=&quot;html_f329d624075ca58041e387489bf32932&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;San Francisco&lt;/div&gt;`)[0];
#                 popup_9881b63a7d14793784664057c3d02149.setContent(html_f329d624075ca58041e387489bf32932);
#
#
#
#         marker_bccb0f070479d0755433e81edefde36c.bindPopup(popup_9881b63a7d14793784664057c3d02149)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
