# %% [markdown]
# [Reference](https://medium.com/swlh/histograms-with-matplotlib-in-python-fc6702a9cb9b)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
plt.style.use("fivethirtyeight")

# %%
data = np.random.randn(1000)
plt.hist(data)
# Out:
# (array([  1.,   7.,  43., 136., 249., 282., 189.,  70.,  17.,   6.]),
#  array([-3.67813388, -2.97108623, -2.26403858, -1.55699093, -0.84994328,
#         -0.14289563,  0.56415202,  1.27119967,  1.97824732,  2.68529497,
#          3.39234262]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data)
plt.title("My Histograms")
plt.xlabel("Values")
plt.ylabel("Frequencies")
# Out:
# Text(0, 0.5, 'Frequencies')

# %%
plt.hist(data, edgecolor="black")
plt.title("My Histograms")
plt.xlabel("Values")
plt.ylabel("Frequencies")
# Out:
# Text(0, 0.5, 'Frequencies')

# %%
plt.hist(data, edgecolor="black", bins=10)
plt.title("My Histograms")
plt.xlabel("Values")
plt.ylabel("Frequencies")
# Out:
# Text(0, 0.5, 'Frequencies')

# %%
bins=[-3,-2,-1,0,1,2,3]
plt.hist(data, edgecolor="black", bins=bins)
plt.title("My Histograms")
plt.xlabel("Values")
plt.ylabel("Frequencies")
# Out:
# Text(0, 0.5, 'Frequencies')

# %%
median=np.median(data)
plt.hist(data, edgecolor="black", bins=bins)
plt.title("My Histograms")
plt.xlabel("Values")
plt.ylabel("Frequencies")
plt.axvline(median, color="red")

# %% [markdown]
# # Comparing the histograms

# %%
x1= np.random.normal(0, 0.8, 1000)
x2= np.random.normal(-3, 2, 1000)
x3= np.random.normal(2, 1, 1000)

# %%
plt.hist(x1, histtype="stepfilled",
         alpha=0.5, bins=40)
plt.hist(x2, histtype="stepfilled",
         alpha=0.5, bins=40)
plt.hist(x3, histtype="stepfilled",
         alpha=0.5, bins=40)
# Out:
# (array([ 3.,  2.,  2.,  7.,  6., 10.,  5., 15., 19., 26., 29., 45., 41.,
#         38., 41., 64., 57., 60., 58., 51., 66., 57., 46., 42., 34., 41.,
#         30., 27., 23., 15., 10.,  3.,  6.,  9.,  2.,  6.,  0.,  3.,  0.,
#          1.]),
#  array([-0.90863011, -0.75221578, -0.59580145, -0.43938712, -0.28297278,
#         -0.12655845,  0.02985588,  0.18627021,  0.34268454,  0.49909888,
#          0.65551321,  0.81192754,  0.96834187,  1.12475621,  1.28117054,
#          1.43758487,  1.5939992 ,  1.75041354,  1.90682787,  2.0632422 ,
#          2.21965653,  2.37607086,  2.5324852 ,  2.68889953,  2.84531386,
#          3.00172819,  3.15814253,  3.31455686,  3.47097119,  3.62738552,
#          3.78379986,  3.94021419,  4.09662852,  4.25304285,  4.40945718,
#          4.56587152,  4.72228585,  4.87870018,  5.03511451,  5.19152885,
#          5.34794318]),
#  <a list of 1 Patch objects>)

# %% [markdown]
# # Two-dimensional histograms

# %%
mean = [0,0]
cov = [[1,1], [1,2]]
x, y = np.random.multivariate_normal(mean,
                                     cov,
                                     10000).T

# %%
plt.hist2d(x, y, bins=30, cmap='Reds')
plt.show()

# %%
plt.hist2d(x, y, bins=30, cmap='Reds')
cb = plt.colorbar()
cb.set_label('Number of rectangles')
