# %% [markdown]
# [Reference](https://medium.com/@ajosegun_/real-time-dashboard-in-python-b8c9a9c4e050)

# %%
# Import necessary modules

import requests
import pandas as pd
import plotly.express as px
import datetime

# %%
city_bike_networks = requests.get("http://api.citybik.es/v2/networks").json()

# %%
def get_city_data(city):
    
  city_bike_networks = requests.get("http://api.citybik.es/v2/networks").json()

  list_of_dicts = []
  for city_bike_dict in city_bike_networks['networks']:
      new_city = city_bike_dict['location']['city']
      if new_city.lower() == city.lower():
          list_of_dicts.append(city_bike_dict)
          
  return list_of_dicts

# %%
city_names = ['Stavanger', 'Copenhagen', 'Utrecht', 'Alhama de Murcia', 'Aranjuez', 'Paris']

for each_city in city_names:
    print(get_city_data(each_city))
    print("-----------------------------\n")
# Out:
# [{'company': ['Gobike A/S'], 'href': '/v2/networks/bysykkelen', 'id': 'bysykkelen', 'location': {'city': 'Stavanger', 'country': 'NO', 'latitude': 58.969975, 'longitude': 5.733107}, 'name': 'Bysykkelen'}]
# -----------------------------
#
# [{'company': ['Gobike A/S'], 'href': '/v2/networks/bycyklen', 'id': 'bycyklen', 'location': {'city': 'Copenhagen', 'country': 'DK', 'latitude': 55.673582, 'longitude': 12.564984}, 'name': 'Bycyklen'}]
# -----------------------------
#
# [{'company': ['Gobike A/S'], 'href': '/v2/networks/nu-connect', 'id': 'nu-connect', 'location': {'city': 'Utrecht', 'country': 'NL', 'latitude': 52.117, 'longitude': 5.067}, 'name': 'Nu-Connect'}]
# -----------------------------
#
# [{'company': ['Domoblue'], 'href': '/v2/networks/onroll-alhama-de-murcia', 'id': 'onroll-alhama-de-murcia', 'location': {'city': 'Alhama de Murcia', 'country': 'ES', 'latitude': 37.849831, 'longitude': -1.424891}, 'name': 'Onroll'}]
# -----------------------------
#
# [{'company': ['Domoblue'], 'href': '/v2/networks/onroll-aranjuez', 'id': 'onroll-aranjuez', 'location': {'city': 'Aranjuez', 'country': 'ES', 'latitude': 40.03097, 'longitude': -3.605742}, 'name': 'Onroll'}]
# -----------------------------
#
# [{'company': None, 'ebikes': True, 'gbfs_href': 'https://velib-metropole-opendata.smoove.pro/opendata/Velib_Metropole/gbfs.json', 'href': '/v2/networks/velib', 'id': 'velib', 'license': {'name': 'OPEN LICENCE 2.0', 'url': 'etalab.gouv.fr/wp-content/uploads/2018/11/open-licence.pdf'}, 'location': {'city': 'Paris', 'country': 'FR', 'latitude': 48.856614, 'longitude': 2.3522219}, 'name': "Velib' Métropôle"}]
# -----------------------------

# %%
get_city_data("Paris")
# Out:
# [{'company': None,
#   'ebikes': True,
#   'gbfs_href': 'https://velib-metropole-opendata.smoove.pro/opendata/Velib_Metropole/gbfs.json',
#   'href': '/v2/networks/velib',
#   'id': 'velib',
#   'license': {'name': 'OPEN LICENCE 2.0',
#    'url': 'etalab.gouv.fr/wp-content/uploads/2018/11/open-licence.pdf'},
#   'location': {'city': 'Paris',
#    'country': 'FR',
#    'latitude': 48.856614,
#    'longitude': 2.3522219},
#   'name': "Velib' Métropôle"}]

# %%
def get_stations_info(city):
    
    station_dict = get_city_data(city)
    if not station_dict:
        print("Error: No bike company found for {}".format(city))
        return None

    network_address = station_dict[0]['href']
    url = "http://api.citybik.es/{}".format(network_address)
    return requests.get(url).json()['network']['stations']

# %%
city = "Paris"
station_info = get_stations_info(city)
station_info
# Out:
# [{'empty_slots': 21,
#   'extra': {'banking': False,
#    'ebikes': 1,
#    'last_updated': 1652397507,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 213688169,
#    'uid': '16107'},
#   'free_bikes': 14,
#   'id': '78ec9186acd18a0b30bd3156d24b9f8d',
#   'latitude': 48.865983,
#   'longitude': 2.275725,
#   'name': 'Benjamin Godard - Victor Hugo',
#   'timestamp': '2022-05-13T00:18:03.514000Z'},
#  {'empty_slots': 53,
#   'extra': {'banking': True,
#    'ebikes': 1,
#    'last_updated': 1652397672,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 99950133,
#    'uid': '6015'},
#   'free_bikes': 2,
#   'id': '43c856353b954711f2bbee185a1f9d04',
#   'latitude': 48.85375581057431,
#   'longitude': 2.3390958085656166,
#   'name': 'André Mazet - Saint-André des Arts',
#   'timestamp': '2022-05-13T00:18:03.381000Z'},
#  {'empty_slots': 30,
#   'extra': {'banking': True,
#    'ebikes': 3,
#    'last_updated': 1652397574,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 312165511,
#    'uid': '11037'},
#   'free_bikes': 4,
#   'id': '9b2700f3b19beb1dd9df2fd6a013789f',
#   'latitude': 48.867872484749,
#   'longitude': 2.3648982158072,
#   'name': 'Faubourg Du Temple - Republique',
#   'timestamp': '2022-05-13T00:18:00.418000Z'},
#  {'empty_slots': 16,
#   'extra': {'banking': True,
#    'ebikes': 1,
#    'last_updated': 1652397386,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 210405211,
#    'uid': '6021'},
#   'free_bikes': 1,
#   'id': '80778031e1a033712bfc3a27a190d5dd',
#   'latitude': 48.856451985395786,
#   'longitude': 2.334851883351803,
#   'name': 'Beaux-Arts - Bonaparte',
#   'timestamp': '2022-05-13T00:18:00.755000Z'},
#  {'empty_slots': 15,
#   'extra': {'banking': True,
#    'ebikes': 4,
#    'last_updated': 1652397390,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 36255,
#    'uid': '9020'},
#   'free_bikes': 6,
#   'id': 'f8f9ec30d28856f9b7fad103be9e4674',
#   'latitude': 48.87929591733507,
#   'longitude': 2.3373600840568547,
#   'name': 'Toudouze - Clauzel',
#   'timestamp': '2022-05-13T00:18:00.823000Z'},
#  {'empty_slots': 1,
#   'extra': {'banking': False,
#    'ebikes': 9,
#    'last_updated': 1652397643,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 516709288,
#    'uid': '11104'},
#   'free_bikes': 19,
#   'id': '59f355492ad3a784fdba53e67467b207',
#   'latitude': 48.85590755596891,
#   'longitude': 2.3925706744194035,
#   'name': 'Charonne - Robert et Sonia Delauney',
#   'timestamp': '2022-05-13T00:18:02.602000Z'},
#  {'empty_slots': 1,
#   'extra': {'banking': False,
#    'ebikes': 4,
#    'last_updated': 1652397605,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 37815204,
#    'uid': '12109'},
#   'free_bikes': 27,
#   'id': '6e0dbb5b877eec618e2b40acdfcc6bb8',
#   'latitude': 48.840855311763,
#   'longitude': 2.3875549435616,
#   'name': 'Mairie du 12ème',
#   'timestamp': '2022-05-13T00:18:00.376000Z'},
#  {'empty_slots': 56,
#   'extra': {'banking': True,
#    'ebikes': 2,
#    'last_updated': 1652397251,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 210566542,
#    'uid': '7003'},
#   'free_bikes': 2,
#   'id': '268880c2481e7aa03975a7f4ee985945',
#   'latitude': 48.851296433665276,
#   'longitude': 2.325061820447445,
#   'name': 'Square Boucicaut',
#   'timestamp': '2022-05-13T00:18:03.329000Z'},
#  {'empty_slots': 45,
#   'extra': {'banking': True,
#    'ebikes': 0,
#    'last_updated': 1652397535,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 100769544,
#    'uid': '5001'},
#   'free_bikes': 0,
#   'id': '11d2a821689732b32a0b4178425a3189',
#   'latitude': 48.85151881501689,
#   'longitude': 2.343670316040516,
#   'name': 'Harpe - Saint-Germain',
#   'timestamp': '2022-05-13T00:18:00.987000Z'},
#  {'empty_slots': 26,
#   'extra': {'banking': True,
#    'ebikes': 9,
#    'last_updated': 1652397594,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 54000559,
#    'uid': '17026'},
#   'free_bikes': 13,
#   'id': '9468274d3c6d8dd8c367c4b8650c869e',
#   'latitude': 48.881973298351625,
#   'longitude': 2.301132157444954,
#   'name': "Jouffroy d'Abbans - Wagram",
#   'timestamp': '2022-05-13T00:18:02.625000Z'},
#  {'empty_slots': 24,
#   'extra': {'banking': True,
#    'ebikes': 4,
#    'last_updated': 1652397589,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 85043758,
#    'uid': '17041'},
#   'free_bikes': 10,
#   'id': 'c9edcdf32809c955e2ab833381c149a2',
#   'latitude': 48.88287775178599,
#   'longitude': 2.287667370814871,
#   'name': 'Guersant - Gouvion-Saint-Cyr',
#   'timestamp': '2022-05-13T00:18:00.661000Z'},
#  {'empty_slots': 29,
#   'extra': {'banking': True,
#    'ebikes': 0,
#    'last_updated': 1652397603,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 123095125,
#    'uid': '10013'},
#   'free_bikes': 28,
#   'id': '45c2573f9bb3d58a288af4247ff3f406',
#   'latitude': 48.8710440519842,
#   'longitude': 2.366104461987773,
#   'name': 'Alibert - Jemmapes',
#   'timestamp': '2022-05-13T00:18:00.589000Z'},
#  {'empty_slots': 16,
#   'extra': {'banking': True,
#    'ebikes': 1,
#    'last_updated': 1652397668,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 129026597,
#    'uid': '9104'},
#   'free_bikes': 1,
#   'id': '7d145bbd89111d7193b951dfc6c02487',
#   'latitude': 48.874422773426545,
#   'longitude': 2.3284685611724854,
#   'name': 'Caumartin - Provence',
#   'timestamp': '2022-05-13T00:18:03.180000Z'},
#  {'empty_slots': 23,
#   'extra': {'banking': True,
#    'ebikes': 1,
#    'last_updated': 1652397123,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 251039991,
#    'uid': '14111'},
#   'free_bikes': 2,
#   'id': 'ff7997b9155b49ebda0f3e7ea20e4d89',
#   'latitude': 48.83752583906732,
#   'longitude': 2.336035408079624,
#   'name': 'Cassini - Denfert-Rochereau',
#   'timestamp': '2022-05-13T00:18:01.090000Z'},
#  {'empty_slots': 17,
#   'extra': {'banking': True,
#    'ebikes': 2,
#    'last_updated': 1652397647,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 37874517,
#    'uid': '6003'},
#   'free_bikes': 2,
#   'id': 'f0ced785f9435ff9284445a1897856e1',
#   'latitude': 48.85165383178419,
#   'longitude': 2.3308077827095985,
#   'name': 'Saint-Sulpice',
#   'timestamp': '2022-05-13T00:18:00.396000Z'},
#  {'empty_slots': 17,
#   'extra': {'banking': False,
#    'ebikes': 0,
#    'last_updated': 1652397399,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 210567545,
#    'uid': '7004'},
#   'free_bikes': 0,
#   'id': 'd1d88931b3ec2bdadebae98bce0a775d',
#   'latitude': 48.85314781654488,
#   'longitude': 2.3263905197381973,
#   'name': 'Raspail - Varenne',
#   'timestamp': '2022-05-13T00:18:00.292000Z'},
#  {'empty_slots': 16,
#   'extra': {'banking': True,
#    'ebikes': 0,
#    'last_updated': 1652397562,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 210403080,
#    'uid': '5110'},
#   'free_bikes': 6,
#   'id': '8ab5dcca384aad21e3b083a30d6ae263',
#   'latitude': 48.84389286531899,
#   'longitude': 2.3519663885235786,
#   'name': 'Lacépède - Monge',
#   'timestamp': '2022-05-13T00:18:03.473000Z'},
#  {'empty_slots': 13,
#   'extra': {'banking': False,
#    'ebikes': 1,
#    'last_updated': 1652397504,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 210561800,
#    'uid': '6108'},
#   'free_bikes': 3,
#   'id': '7d6ba3781c835c4a552b373689b71188',
#   'latitude': 48.84708159081946,
#   'longitude': 2.321374788880348,
#   'name': 'Saint-Romain - Cherche-Midi',
#   'timestamp': '2022-05-13T00:18:00.690000Z'},
#  {'empty_slots': 13,
#   'extra': {'banking': False,
#    'ebikes': 7,
#    'last_updated': 1652397443,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 209063434,
#    'uid': '33006'},
#   'free_bikes': 17,
#   'id': '0e3c0f14de288ac43c5a8b0a1cbc33b9',
#   'latitude': 48.91039875761846,
#   'longitude': 2.3851355910301213,
#   'name': 'André Karman - République',
#   'timestamp': '2022-05-13T00:18:00.840000Z'},
#  {'empty_slots': 1,
#   'extra': {'banking': False,
#    'ebikes': 19,
#    'last_updated': 1652397661,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 94555589,
#    'uid': '42016'},
#   'free_bikes': 25,
#   'id': '036b6154355561cef963080cc32a2dbd',
#   'latitude': 48.81580226360801,
#   'longitude': 2.376804985105991,
#   'name': 'Pierre et Marie Curie - Maurice Thorez',
#   'timestamp': '2022-05-13T00:18:00.828000Z'},
#  {'empty_slots': 7,
#   'extra': {'banking': True,
#    'ebikes': 17,
#    'last_updated': 1652397391,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 244498842,
#    'uid': '41301'},
#   'free_bikes': 40,
#   'id': 'd16fc1f39f76274493aa77c45f2b36e5',
#   'latitude': 48.836022242886884,
#   'longitude': 2.4708339950830287,
#   'name': 'Bois de Vincennes - Gare',
#   'timestamp': '2022-05-13T00:18:00.298000Z'},
#  {'empty_slots': 5,
#   'extra': {'banking': True,
#    'ebikes': 6,
#    'last_updated': 1652397482,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 43195240,
#    'uid': '21010'},
#   'free_bikes': 19,
#   'id': 'b5e0ce34d56d5a00d64947b6045b9fdc',
#   'latitude': 48.835583838705936,
#   'longitude': 2.2325500845909123,
#   'name': 'Silly - Galliéni',
#   'timestamp': '2022-05-13T00:18:02.559000Z'},
#  {'empty_slots': 15,
#   'extra': {'banking': True,
#    'ebikes': 6,
#    'last_updated': 1652397444,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 501862076,
#    'uid': '25006'},
#   'free_bikes': 6,
#   'id': '17f036f2bcf0225fd7bcf61662325e13',
#   'latitude': 48.862090937689715,
#   'longitude': 2.196576297283173,
#   'name': 'Place Nelson Mandela ',
#   'timestamp': '2022-05-13T00:18:00.875000Z'},
#  {'empty_slots': 28,
#   'extra': {'banking': True,
#    'ebikes': 4,
#    'last_updated': 1652397659,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 66491398,
#    'uid': '13007'},
#   'free_bikes': 20,
#   'id': '6a847ac4b705e2863bba9460a0b320fe',
#   'latitude': 48.835092787823875,
#   'longitude': 2.353468135133752,
#   'name': 'Le Brun - Gobelins',
#   'timestamp': '2022-05-13T00:18:01.580000Z'},
#  {'empty_slots': 20,
#   'extra': {'banking': True,
#    'ebikes': 2,
#    'last_updated': 1652397654,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 653062048,
#    'uid': '10152'},
#   'free_bikes': 3,
#   'id': 'ac090301d156f8658f2421b14e637615',
#   'latitude': 48.879089,
#   'longitude': 2.354235,
#   'name': 'Gare du Nord - Place de Valenciennes',
#   'timestamp': '2022-05-13T00:18:00.942000Z'},
#  {'empty_slots': 44,
#   'extra': {'banking': True,
#    'ebikes': 0,
#    'last_updated': 1652397627,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 207633746,
#    'uid': '17038'},
#   'free_bikes': 1,
#   'id': 'a497dc1ed4a61b01828f0f64ba00aec4',
#   'latitude': 48.876116,
#   'longitude': 2.288124,
#   'name': 'Grande Armée - Brunel',
#   'timestamp': '2022-05-13T00:18:03.289000Z'},
#  {'empty_slots': 6,
#   'extra': {'banking': False,
#    'ebikes': 12,
#    'last_updated': 1652397464,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 1333959209,
#    'uid': '44012'},
#   'free_bikes': 13,
#   'id': 'a1608bb58dff0b09b90fc7a0f4955d83',
#   'latitude': 48.794902381218904,
#   'longitude': 2.3734183609485626,
#   'name': 'Génie - Mozart',
#   'timestamp': '2022-05-13T00:18:02.363000Z'},
#  {'empty_slots': 16,
#   'extra': {'banking': False,
#    'ebikes': 0,
#    'last_updated': 1652397234,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 210397939,
#    'uid': '5016'},
#   'free_bikes': 1,
#   'id': '77d33d7defdf65816fbd6a5919b0b299',
#   'latitude': 48.84504716661511,
#   'longitude': 2.3494647851273465,
#   'name': 'Thouin - Cardinal Lemoine',
#   'timestamp': '2022-05-13T00:18:00.684000Z'},
#  {'empty_slots': 14,
#   'extra': {'banking': True,
#    'ebikes': 1,
#    'last_updated': 1652397627,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 82405965,
#    'uid': '11025'},
#   'free_bikes': 28,
#   'id': '75577927f1cca5915590bc2d46e1b5c8',
#   'latitude': 48.8570414504784,
#   'longitude': 2.37289470306807,
#   'name': 'Froment - Bréguet',
#   'timestamp': '2022-05-13T00:18:00.665000Z'},
#  {'empty_slots': 18,
#   'extra': {'banking': True,
#    'ebikes': 1,
#    'last_updated': 1652397433,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 27414578,
#    'uid': '6006'},
#   'free_bikes': 1,
#   'id': 'b36411fb0a33a59d977438de7a3dbd3e',
#   'latitude': 48.84479928858768,
#   'longitude': 2.329337755887181,
#   'name': 'Notre-Dame-des-Champs - Stanislas',
#   'timestamp': '2022-05-13T00:18:01.008000Z'},
#  {'empty_slots': 1,
#   'extra': {'banking': False,
#    'ebikes': 22,
#    'last_updated': 1652397598,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 213682736,
#    'uid': '15047'},
#   'free_bikes': 49,
#   'id': '7268faf54f66d26bfcde7f0cf3396b50',
#   'latitude': 48.83310149953933,
#   'longitude': 2.299380004405976,
#   'name': 'Morillons - Dantzig',
#   'timestamp': '2022-05-13T00:18:00.662000Z'},
#  {'empty_slots': 5,
#   'extra': {'banking': True,
#    'ebikes': 1,
#    'last_updated': 1652397672,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 85008390,
#    'uid': '15028'},
#   'free_bikes': 65,
#   'id': '2937695fcc7dc6bc7669a8f85fd6d90c',
#   'latitude': 48.851315406715976,
#   'longitude': 2.2919502854347233,
#   'name': 'Grenelle - Dr Finlay',
#   'timestamp': '2022-05-13T00:18:00.196000Z'},
#  {'empty_slots': 31,
#   'extra': {'banking': True,
#    'ebikes': 2,
#    'last_updated': 1652397352,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 80101533,
#    'uid': '17025'},
#   'free_bikes': 4,
#   'id': 'bf673f18227a42a5dcc3da272b83a8e9',
#   'latitude': 48.879406604954,
#   'longitude': 2.3034455627202988,
#   'name': 'Chazelles - Courcelles ',
#   'timestamp': '2022-05-13T00:18:00.228000Z'},
#  {'empty_slots': 25,
#   'extra': {'banking': True,
#    'ebikes': 2,
#    'last_updated': 1652397671,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 54000581,
#    'uid': '13101'},
#   'free_bikes': 8,
#   'id': 'fceca1139eb3598f85221418a2eed143',
#   'latitude': 48.830981659316855,
#   'longitude': 2.3481646925210953,
#   'name': 'Croulebarde - Corvisart',
#   'timestamp': '2022-05-13T00:18:02.704000Z'},
#  {'empty_slots': 25,
#   'extra': {'banking': True,
#    'ebikes': 8,
#    'last_updated': 1652397631,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 599135701,
#    'uid': '20143'},
#   'free_bikes': 17,
#   'id': 'ff22697fcb655df134aa23e633587ca6',
#   'latitude': 48.871031137596,
#   'longitude': 2.379056852114,
#   'name': 'Ramponeau - Belleville',
#   'timestamp': '2022-05-13T00:18:01.916000Z'},
#  {'empty_slots': 14,
#   'extra': {'banking': False,
#    'ebikes': 4,
#    'last_updated': 1652397637,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 13105968,
#    'uid': '14108'},
#   'free_bikes': 6,
#   'id': '06a1142ebde3cb6346c4a4fc864c5dc2',
#   'latitude': 48.82234096593411,
#   'longitude': 2.327861653302471,
#   'name': 'Le Brix et Mesmin - Jourdan',
#   'timestamp': '2022-05-13T00:18:02.525000Z'},
#  {'empty_slots': 29,
#   'extra': {'banking': False,
#    'ebikes': 7,
#    'last_updated': 1652397455,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 653208733,
#    'uid': '31024'},
#   'free_bikes': 9,
#   'id': '09d581adc5efda8a6e0c2eff61397cc2',
#   'latitude': 48.86785,
#   'longitude': 2.446748,
#   'name': 'Romainville - Vaillant-Couturier',
#   'timestamp': '2022-05-13T00:18:00.780000Z'},
#  {'empty_slots': 15,
#   'extra': {'banking': False,
#    'ebikes': 1,
#    'last_updated': 1652397112,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 506455295,
#    'uid': '15068'},
#   'free_bikes': 1,
#   'id': '6eb8825f820d60b3d97416cf5aa6d06b',
#   'latitude': 48.83823094269141,
#   'longitude': 2.270506024360657,
#   'name': 'Général Martial Valin - Pont du Garigliano',
#   'timestamp': '2022-05-13T00:18:00.436000Z'},
#  {'empty_slots': 1,
#   'extra': {'banking': True,
#    'ebikes': 1,
#    'last_updated': 1652397660,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 907054879,
#    'uid': '47007'},
#   'free_bikes': 19,
#   'id': 'b72bbb7eb5c7086e574f95846674e2f6',
#   'latitude': 48.79014780960843,
#   'longitude': 2.43286281824112,
#   'name': 'Liberté - Vert-de-Maisons',
#   'timestamp': '2022-05-13T00:18:02.457000Z'},
#  {'empty_slots': 34,
#   'extra': {'banking': False,
#    'ebikes': 4,
#    'last_updated': 1652397603,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 129094535,
#    'uid': '17044'},
#   'free_bikes': 6,
#   'id': 'cf0dcc3cdde692e1fca56a31ff549fff',
#   'latitude': 48.89792240854517,
#   'longitude': 2.32851451022192,
#   'name': 'Porte de Saint-Ouen - Bessières',
#   'timestamp': '2022-05-13T00:18:01.403000Z'},
#  {'empty_slots': 10,
#   'extra': {'banking': True,
#    'ebikes': 6,
#    'last_updated': 1652397470,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 27415224,
#    'uid': '15026'},
#   'free_bikes': 21,
#   'id': 'eaa35ac247bece89efd3383bc2c7dad4',
#   'latitude': 48.853844054333514,
#   'longitude': 2.289705348222022,
#   'name': 'Bir Hakeim',
#   'timestamp': '2022-05-13T00:18:01.313000Z'},
#  {'empty_slots': 1,
#   'extra': {'banking': True,
#    'ebikes': 6,
#    'last_updated': 1652397679,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 499303158,
#    'uid': '44017'},
#   'free_bikes': 29,
#   'id': 'c9326a3111d3c44e3ac8114db5b2a677',
#   'latitude': 48.79628807093802,
#   'longitude': 2.417212128639221,
#   'name': "Jules Guesde - Pont du Port à l'Anglais",
#   'timestamp': '2022-05-13T00:18:00.344000Z'},
#  {'empty_slots': 29,
#   'extra': {'banking': False,
#    'ebikes': 0,
#    'last_updated': 1652397572,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 54000612,
#    'uid': '19033'},
#   'free_bikes': 12,
#   'id': '5349a87a2dc217a11ab002391c09f021',
#   'latitude': 48.89594736851349,
#   'longitude': 2.381133802246315,
#   'name': 'Cambrai - Benjamin Constant',
#   'timestamp': '2022-05-13T00:18:02.869000Z'},
#  {'empty_slots': 27,
#   'extra': {'banking': True,
#    'ebikes': 1,
#    'last_updated': 1652397574,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 88230992,
#    'uid': '17048'},
#   'free_bikes': 2,
#   'id': '5cc8f47571f1fbacc37b07b700ded02e',
#   'latitude': 48.882428,
#   'longitude': 2.314002,
#   'name': 'De Toqueville - Terrasse',
#   'timestamp': '2022-05-13T00:18:00.767000Z'},
#  {'empty_slots': 13,
#   'extra': {'banking': False,
#    'ebikes': 8,
#    'last_updated': 1652397563,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 27415302,
#    'uid': '16118'},
#   'free_bikes': 13,
#   'id': '1d59cee64768545a2f6672df4527d9c5',
#   'latitude': 48.840579923690115,
#   'longitude': 2.2584119439125065,
#   'name': 'Michel-Ange - Parent de Rosan',
#   'timestamp': '2022-05-13T00:18:01.336000Z'},
#  {'empty_slots': 15,
#   'extra': {'banking': True,
#    'ebikes': 2,
#    'last_updated': 1652397506,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 102747146,
#    'uid': '43002'},
#   'free_bikes': 9,
#   'id': '90f695e0c1794b98ef78df609ee1af83',
#   'latitude': 48.84884147189881,
#   'longitude': 2.426325418925233,
#   'name': 'Lagny - Victor Basch',
#   'timestamp': '2022-05-13T00:18:00.752000Z'},
#  {'empty_slots': 13,
#   'extra': {'banking': False,
#    'ebikes': 5,
#    'last_updated': 1652397492,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 42950839,
#    'uid': '19027'},
#   'free_bikes': 5,
#   'id': 'ef6f3e60f8625a95574d4ba5cf0db701',
#   'latitude': 48.8804934032465,
#   'longitude': 2.39806417375803,
#   'name': 'Serrurier',
#   'timestamp': '2022-05-13T00:18:00.234000Z'},
#  {'empty_slots': 5,
#   'extra': {'banking': False,
#    'ebikes': 15,
#    'last_updated': 1652397527,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 653197324,
#    'uid': '92002'},
#   'free_bikes': 18,
#   'id': 'dcde9d0eedef52a437a0a6fbd1b4c19e',
#   'latitude': 48.89264852683893,
#   'longitude': 2.2136941552162175,
#   'name': 'Théâtre des Amandiers - Palais des sports',
#   'timestamp': '2022-05-13T00:18:00.198000Z'},
#  {'empty_slots': 18,
#   'extra': {'banking': False,
#    'ebikes': 3,
#    'last_updated': 1652397482,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 653132534,
#    'uid': '21216'},
#   'free_bikes': 7,
#   'id': '6dfb5192fb139d203175e04219fea536',
#   'latitude': 48.81807418981508,
#   'longitude': 2.3267009854316716,
#   'name': 'Louis Lejeune - Barbès',
#   'timestamp': '2022-05-13T00:18:01.212000Z'},
#  {'empty_slots': 22,
#   'extra': {'banking': True,
#    'ebikes': 3,
#    'last_updated': 1652397430,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 210408693,
#    'uid': '6029'},
#   'free_bikes': 3,
#   'id': '060b5cdb163a466a33c867a3d3d643ee',
#   'latitude': 48.848951441614176,
#   'longitude': 2.3411329463124275,
#   'name': 'Vaugirard - Monsieur le Prince',
#   'timestamp': '2022-05-13T00:18:01.751000Z'},
#  {'empty_slots': 3,
#   'extra': {'banking': False,
#    'ebikes': 8,
#    'last_updated': 1652397658,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 1057149522,
#    'uid': '22207'},
#   'free_bikes': 19,
#   'id': '76d95de2fa489b3287c50f7b8fa43992',
#   'latitude': 48.78980918988166,
#   'longitude': 2.3143940046429634,
#   'name': 'Rond-point du Dr Albert Schweitzer',
#   'timestamp': '2022-05-13T00:18:01.260000Z'},
#  {'empty_slots': 31,
#   'extra': {'banking': True,
#    'ebikes': 1,
#    'last_updated': 1652397628,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 128986726,
#    'uid': '8050'},
#   'free_bikes': 1,
#   'id': '146ba8cb83644c5f97a41aef5d403646',
#   'latitude': 48.871417284354834,
#   'longitude': 2.307678759098053,
#   'name': 'Boétie - Ponthieu',
#   'timestamp': '2022-05-13T00:18:00.859000Z'},
#  {'empty_slots': 9,
#   'extra': {'banking': True,
#    'ebikes': 29,
#    'last_updated': 1652397644,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 15433394,
#    'uid': '18015'},
#   'free_bikes': 31,
#   'id': '94426ad2d7f2d578154b9fc0741e50a6',
#   'latitude': 48.888735896947054,
#   'longitude': 2.3469526693224907,
#   'name': 'Custine - Ramey',
#   'timestamp': '2022-05-13T00:18:03.433000Z'},
#  {'empty_slots': 15,
#   'extra': {'banking': False,
#    'ebikes': 6,
#    'last_updated': 1652397457,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 85123644,
#    'uid': '20035'},
#   'free_bikes': 10,
#   'id': '5c2cc3d86482f8eb7a2024c4c0a6c6a7',
#   'latitude': 48.8693268535238,
#   'longitude': 2.395084574818611,
#   'name': 'Pyrénées - Ménilmontant',
#   'timestamp': '2022-05-13T00:18:00.323000Z'},
#  {'empty_slots': 38,
#   'extra': {'banking': False,
#    'ebikes': 0,
#    'last_updated': 1652397483,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 27414512,
#    'uid': '2017'},
#   'free_bikes': 0,
#   'id': 'f6f2086e5cd5a502faa6b5428626721c',
#   'latitude': 48.86785342111862,
#   'longitude': 2.349364310503006,
#   'name': 'Caire - Dussoubs',
#   'timestamp': '2022-05-13T00:18:00.989000Z'},
#  {'empty_slots': 10,
#   'extra': {'banking': False,
#    'ebikes': 3,
#    'last_updated': 1652397427,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 210580039,
#    'uid': '9008'},
#   'free_bikes': 7,
#   'id': 'ed48e8a94a3b5e6f3cd48e0ecce358a5',
#   'latitude': 48.879161,
#   'longitude': 2.343698,
#   'name': "Tour d'Auvergne - Rodier",
#   'timestamp': '2022-05-13T00:18:01.259000Z'},
#  {'empty_slots': 61,
#   'extra': {'banking': True,
#    'ebikes': 0,
#    'last_updated': 1652397471,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 210568512,
#    'uid': '7009'},
#   'free_bikes': 2,
#   'id': 'eb3335b8528855e4669ddd490118c97f',
#   'latitude': 48.86141101465194,
#   'longitude': 2.320121418520769,
#   'name': 'Assemblée Nationale',
#   'timestamp': '2022-05-13T00:18:00.446000Z'},
#  {'empty_slots': 13,
#   'extra': {'banking': False,
#    'ebikes': 4,
#    'last_updated': 1652397654,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 210585225,
#    'uid': '10027'},
#   'free_bikes': 6,
#   'id': 'd41d50eb287ee527848755b3a31ee559',
#   'latitude': 48.879355,
#   'longitude': 2.358379,
#   'name': 'Dunkerque - Alsace',
#   'timestamp': '2022-05-13T00:18:00.518000Z'},
#  {'empty_slots': 18,
#   'extra': {'banking': False,
#    'ebikes': 0,
#    'last_updated': 1652397630,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 128940135,
#    'uid': '8048'},
#   'free_bikes': 0,
#   'id': 'b558d7d5bdea63c98f68cd8d32524d39',
#   'latitude': 48.86883394989261,
#   'longitude': 2.2989967837929726,
#   'name': 'Marceau - Chaillot',
#   'timestamp': '2022-05-13T00:18:02.178000Z'},
#  {'empty_slots': 3,
#   'extra': {'banking': True,
#    'ebikes': 6,
#    'last_updated': 1652397362,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 35149611,
#    'uid': '14013'},
#   'free_bikes': 11,
#   'id': '9eca9e39a4bd2df5f0a272db2c944f15',
#   'latitude': 48.8214169,
#   'longitude': 2.342167,
#   'name': 'Liard - Amiral Mouchez',
#   'timestamp': '2022-05-13T00:18:01.973000Z'},
#  {'empty_slots': 12,
#   'extra': {'banking': True,
#    'ebikes': 1,
#    'last_updated': 1652397606,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 55927887,
#    'uid': '12031'},
#   'free_bikes': 22,
#   'id': '1543bd52c06ef5bdb4d4b5ee34cc486a',
#   'latitude': 48.8351212784276,
#   'longitude': 2.385534569621086,
#   'name': 'Gabriel Lamé',
#   'timestamp': '2022-05-13T00:18:00.408000Z'},
#  {'empty_slots': 22,
#   'extra': {'banking': False,
#    'ebikes': 0,
#    'last_updated': 1652397561,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 210570888,
#    'uid': '7011'},
#   'free_bikes': 0,
#   'id': '5cb98cdf20ab69563923aed8167ae8a9',
#   'latitude': 48.85909110474066,
#   'longitude': 2.3185685276985173,
#   'name': 'Las Cases - Bourgogne',
#   'timestamp': '2022-05-13T00:18:00.867000Z'},
#  {'empty_slots': 5,
#   'extra': {'banking': False,
#    'ebikes': 18,
#    'last_updated': 1652397352,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 129107656,
#    'uid': '18111'},
#   'free_bikes': 20,
#   'id': 'fe5431d0976be760a51e34e21383f0f9',
#   'latitude': 48.88949630486821,
#   'longitude': 2.333393658804396,
#   'name': 'Félix Ziem - Armand Gauthier',
#   'timestamp': '2022-05-13T00:18:00.528000Z'},
#  {'empty_slots': 26,
#   'extra': {'banking': True,
#    'ebikes': 2,
#    'last_updated': 1652397517,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 129088667,
#    'uid': '17010'},
#   'free_bikes': 14,
#   'id': 'ee5f8237d94f94862fac6e27c8f1c348',
#   'latitude': 48.894799816683985,
#   'longitude': 2.318705212173216,
#   'name': 'Jonquière - Docteur Paul Brousse',
#   'timestamp': '2022-05-13T00:18:03.068000Z'},
#  {'empty_slots': 24,
#   'extra': {'banking': True,
#    'ebikes': 0,
#    'last_updated': 1652397554,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 128930462,
#    'uid': '8016'},
#   'free_bikes': 1,
#   'id': '67447a40039cae5e6f47f8ffb8fd2b26',
#   'latitude': 48.87320440102894,
#   'longitude': 2.323658830743138,
#   'name': 'Square Louis XVI',
#   'timestamp': '2022-05-13T00:18:01.300000Z'},
#  {'empty_slots': 15,
#   'extra': {'banking': False,
#    'ebikes': 6,
#    'last_updated': 1652397160,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 1057228658,
#    'uid': '48003'},
#   'free_bikes': 7,
#   'id': '55d766b2cfd797e5962b8a5133cb9a33',
#   'latitude': 48.78448485079149,
#   'longitude': 2.35908430069685,
#   'name': 'Youri Gagarine - Karl Marx',
#   'timestamp': '2022-05-13T00:18:00.557000Z'},
#  {'empty_slots': 18,
#   'extra': {'banking': False,
#    'ebikes': 2,
#    'last_updated': 1652397126,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 230873471,
#    'uid': '16110'},
#   'free_bikes': 2,
#   'id': '99678a6a0780e479f54c08a1305d2a2a',
#   'latitude': 48.86106902949534,
#   'longitude': 2.2730283066630363,
#   'name': 'Octave Feuillet - Albéric Magnard',
#   'timestamp': '2022-05-13T00:18:02.319000Z'},
#  {'empty_slots': 16,
#   'extra': {'banking': False,
#    'ebikes': 5,
#    'last_updated': 1652397251,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 507934805,
#    'uid': '18134'},
#   'free_bikes': 9,
#   'id': 'a5816027f41b2799e91b665c95e1938d',
#   'latitude': 48.8978867,
#   'longitude': 2.3458001,
#   'name': 'Ney - Porte de Clignancourt ',
#   'timestamp': '2022-05-13T00:18:02.175000Z'},
#  {'empty_slots': 24,
#   'extra': {'banking': False,
#    'ebikes': 0,
#    'last_updated': 1652397596,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 7254,
#    'uid': '5005'},
#   'free_bikes': 0,
#   'id': '18d63d7f1b3c402d11816c5f07658e57',
#   'latitude': 48.844730256132095,
#   'longitude': 2.341923944866407,
#   'name': 'Gay Lussac - Saint-Jacques',
#   'timestamp': '2022-05-13T00:18:03.021000Z'},
#  {'empty_slots': 11,
#   'extra': {'banking': True,
#    'ebikes': 17,
#    'last_updated': 1652397485,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 129164969,
#    'uid': '43009'},
#   'free_bikes': 37,
#   'id': '27c45001b48e6b0c3965b412f618d813',
#   'latitude': 48.8468428626593,
#   'longitude': 2.452062070369721,
#   'name': 'Place Jean-Spire-Lemaître',
#   'timestamp': '2022-05-13T00:18:00.524000Z'},
#  {'empty_slots': 28,
#   'extra': {'banking': False,
#    'ebikes': 1,
#    'last_updated': 1652397482,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 128989986,
#    'uid': '8053'},
#   'free_bikes': 1,
#   'id': '9e88938078e837e55a03cf6193682de5',
#   'latitude': 48.874750203956566,
#   'longitude': 2.301771435325988,
#   'name': 'Place Georges Guillaumin',
#   'timestamp': '2022-05-13T00:18:02.520000Z'},
#  {'empty_slots': 9,
#   'extra': {'banking': True,
#    'ebikes': 2,
#    'last_updated': 1652397660,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 129004826,
#    'uid': '9001'},
#   'free_bikes': 8,
#   'id': '4264d28f99b033dcae11a325376f75b1',
#   'latitude': 48.87759897050706,
#   'longitude': 2.348463758826256,
#   'name': 'Bellefond - Poissonnière',
#   'timestamp': '2022-05-13T00:18:01.790000Z'},
#  {'empty_slots': 20,
#   'extra': {'banking': False,
#    'ebikes': 1,
#    'last_updated': 1652397116,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 518825709,
#    'uid': '17032'},
#   'free_bikes': 1,
#   'id': '67b871714c5747e4b27c22703cf13013',
#   'latitude': 48.88655580065981,
#   'longitude': 2.288640439510346,
#   'name': 'Jean Oestreicher - Porte de Champerret',
#   'timestamp': '2022-05-13T00:18:00.534000Z'},
#  {'empty_slots': 18,
#   'extra': {'banking': True,
#    'ebikes': 2,
#    'last_updated': 1652397673,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 911767210,
#    'uid': '10162'},
#   'free_bikes': 2,
#   'id': 'ffebae556fb025e5425befa8f1a43308',
#   'latitude': 48.87935941942529,
#   'longitude': 2.366596162319184,
#   'name': 'Alexandre Parodi - Quai de Valmy',
#   'timestamp': '2022-05-13T00:18:01.957000Z'},
#  {'empty_slots': 13,
#   'extra': {'banking': False,
#    'ebikes': 3,
#    'last_updated': 1652397581,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 128887067,
#    'uid': '7018'},
#   'free_bikes': 6,
#   'id': 'a41c910adee6a07881812ef4abcd1e5d',
#   'latitude': 48.85141997898257,
#   'longitude': 2.3097044974565506,
#   'name': "Ségur - d'Estrées",
#   'timestamp': '2022-05-13T00:18:00.618000Z'},
#  {'empty_slots': 12,
#   'extra': {'banking': False,
#    'ebikes': 8,
#    'last_updated': 1652397571,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 54000565,
#    'uid': '10115'},
#   'free_bikes': 14,
#   'id': '415e59bd5a8ba4b267518de1c81f0cd2',
#   'latitude': 48.8761373390584,
#   'longitude': 2.3680844979417,
#   'name': 'Granges aux Belles',
#   'timestamp': '2022-05-13T00:18:02.631000Z'},
#  {'empty_slots': 4,
#   'extra': {'banking': False,
#    'ebikes': 5,
#    'last_updated': 1652397557,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 1057296253,
#    'uid': '13118'},
#   'free_bikes': 57,
#   'id': '8a5aed60fc8805d38fdc6f00088538bf',
#   'latitude': 48.82435782216384,
#   'longitude': 2.377065159380436,
#   'name': 'Regnault - Patay',
#   'timestamp': '2022-05-13T00:18:00.925000Z'},
#  {'empty_slots': 40,
#   'extra': {'banking': True,
#    'ebikes': 1,
#    'last_updated': 1652397525,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 210581084,
#    'uid': '9035'},
#   'free_bikes': 1,
#   'id': '0f3ac6a9fb5eb3f43e1a0c1980f05f4a',
#   'latitude': 48.877753,
#   'longitude': 2.327339,
#   'name': 'Gare Saint-Lazare - Place de Budapest',
#   'timestamp': '2022-05-13T00:18:01.942000Z'},
#  {'empty_slots': 43,
#   'extra': {'banking': True,
#    'ebikes': 1,
#    'last_updated': 1652397649,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 205047993,
#    'uid': '14002'},
#   'free_bikes': 2,
#   'id': '894197f05300286868f6ed8858a881c1',
#   'latitude': 48.83940266673835,
#   'longitude': 2.32971478253603,
#   'name': 'Edgar Quinet - Raspail',
#   'timestamp': '2022-05-13T00:18:00.601000Z'},
#  {'empty_slots': 5,
#   'extra': {'banking': True,
#    'ebikes': 18,
#    'last_updated': 1652397545,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 102311820,
#    'uid': '18024'},
#   'free_bikes': 28,
#   'id': 'da851a915c41eb46abc46b738d798530',
#   'latitude': 48.891457726153774,
#   'longitude': 2.348636478060487,
#   'name': 'Clignancourt - Ordener',
#   'timestamp': '2022-05-13T00:18:00.563000Z'},
#  {'empty_slots': 19,
#   'extra': {'banking': False,
#    'ebikes': 1,
#    'last_updated': 1652397469,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 210586093,
#    'uid': '10029'},
#   'free_bikes': 4,
#   'id': '4c195e576b892f6d3350a36e59a52ff3',
#   'latitude': 48.880726,
#   'longitude': 2.351464,
#   'name': 'Dunkerque - Rocroy',
#   'timestamp': '2022-05-13T00:18:00.653000Z'},
#  {'empty_slots': 11,
#   'extra': {'banking': True,
#    'ebikes': 1,
#    'last_updated': 1652397593,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 210574471,
#    'uid': '9002'},
#   'free_bikes': 3,
#   'id': '012b17de09d1300f63c8b63067b39063',
#   'latitude': 48.879223,
#   'longitude': 2.349147,
#   'name': 'Abbeville - Faubourg Poissonnière',
#   'timestamp': '2022-05-13T00:18:03.046000Z'},
#  {'empty_slots': 19,
#   'extra': {'banking': True,
#    'ebikes': 0,
#    'last_updated': 1652397618,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 72765603,
#    'uid': '5022'},
#   'free_bikes': 1,
#   'id': 'c6a39a31a86611c31fb3c34bae46e8f5',
#   'latitude': 48.8462904,
#   'longitude': 2.3521495,
#   'name': 'Boulangers - Cardinal Lemoine',
#   'timestamp': '2022-05-13T00:18:01.067000Z'},
#  {'empty_slots': 13,
#   'extra': {'banking': False,
#    'ebikes': 0,
#    'last_updated': 1652397236,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 210582921,
#    'uid': '9106'},
#   'free_bikes': 1,
#   'id': 'de40d516ab36b574ee1990157165d4ef',
#   'latitude': 48.87219,
#   'longitude': 2.329423,
#   'name': 'Boudreau - Auber',
#   'timestamp': '2022-05-13T00:18:03.316000Z'},
#  {'empty_slots': 23,
#   'extra': {'banking': True,
#    'ebikes': 3,
#    'last_updated': 1652397652,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 369644630,
#    'uid': '10161'},
#   'free_bikes': 5,
#   'id': 'b12be68f3b9115784f498398517c80a0',
#   'latitude': 48.875642647477,
#   'longitude': 2.3594588041306,
#   'name': "Gare de l'Est - Faubourg-Saint-Martin",
#   'timestamp': '2022-05-13T00:18:01.657000Z'},
#  {'empty_slots': 46,
#   'extra': {'banking': True,
#    'ebikes': 0,
#    'last_updated': 1652397270,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 43255030,
#    'uid': '17040'},
#   'free_bikes': 2,
#   'id': '782947ad7a5d7a2455bb62bb3f1647b9',
#   'latitude': 48.87973954830735,
#   'longitude': 2.288012132048607,
#   'name': 'Pereire - Ternes',
#   'timestamp': '2022-05-13T00:18:00.435000Z'},
#  {'empty_slots': 26,
#   'extra': {'banking': False,
#    'ebikes': 1,
#    'last_updated': 1652397527,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 129025451,
#    'uid': '9038'},
#   'free_bikes': 1,
#   'id': '557a0531c4372aa3abe987d7052a8cc7',
#   'latitude': 48.88320784122797,
#   'longitude': 2.3308449949028507,
#   'name': 'Douai - Bruxelles',
#   'timestamp': '2022-05-13T00:18:00.460000Z'},
#  {'empty_slots': 16,
#   'extra': {'banking': True,
#    'ebikes': 1,
#    'last_updated': 1652397658,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 128889359,
#    'uid': '7020'},
#   'free_bikes': 23,
#   'id': '0b0c4f4ae8c238e0b7eaad2c9a2a9325',
#   'latitude': 48.856691550115315,
#   'longitude': 2.306646779179573,
#   'name': 'Champ de Mars - Cler',
#   'timestamp': '2022-05-13T00:18:01.245000Z'},
#  {'empty_slots': 10,
#   'extra': {'banking': True,
#    'ebikes': 2,
#    'last_updated': 1652397477,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 323616530,
#    'uid': '1001'},
#   'free_bikes': 2,
#   'id': 'fe6481666c6964991af2fec0b5573fd3',
#   'latitude': 48.857058739111096,
#   'longitude': 2.341798283943937,
#   'name': "Quai de l'Horloge - Pont Neuf",
#   'timestamp': '2022-05-13T00:18:03.492000Z'},
#  {'empty_slots': 23,
#   'extra': {'banking': True,
#    'ebikes': 2,
#    'last_updated': 1652397375,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 128920403,
#    'uid': '8009'},
#   'free_bikes': 2,
#   'id': 'aa7ead9254a3eeddc94f3a0c1f5401f1',
#   'latitude': 48.874777677621296,
#   'longitude': 2.326515804784655,
#   'name': 'Gare Saint-Lazare - Isly',
#   'timestamp': '2022-05-13T00:18:00.392000Z'},
#  {'empty_slots': 33,
#   'extra': {'banking': True,
#    'ebikes': 0,
#    'last_updated': 1652397437,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 128936618,
#    'uid': '8032'},
#   'free_bikes': 1,
#   'id': '384b7ce5f1caf633bfd384e6b4177448',
#   'latitude': 48.87147859116726,
#   'longitude': 2.313977926969528,
#   'name': 'Matignon - Faubourg Saint-Honoré',
#   'timestamp': '2022-05-13T00:18:00.677000Z'},
#  {'empty_slots': 8,
#   'extra': {'banking': False,
#    'ebikes': 8,
#    'last_updated': 1652397566,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 208795867,
#    'uid': '19105'},
#   'free_bikes': 8,
#   'id': 'fe416377651bc1716038b396302b77e0',
#   'latitude': 48.883667,
#   'longitude': 2.395733,
#   'name': 'Ambroise Rendu - Porte Brunet',
#   'timestamp': '2022-05-13T00:18:02.272000Z'},
#  {'empty_slots': 55,
#   'extra': {'banking': True,
#    'ebikes': 2,
#    'last_updated': 1652397241,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 66491397,
#    'uid': '12151'},
#   'free_bikes': 4,
#   'id': '6cbe15611593e1cffd0a9abf54aeffc8',
#   'latitude': 48.8455150897939,
#   'longitude': 2.3726498446286,
#   'name': 'Gare de Lyon - Place Louis Armand',
#   'timestamp': '2022-05-13T00:18:01.579000Z'},
#  {'empty_slots': 15,
#   'extra': {'banking': True,
#    'ebikes': 0,
#    'last_updated': 1652397482,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 6296,
#    'uid': '6001'},
#   'free_bikes': 0,
#   'id': 'a9bc03f19bd965f2edd21e4292c15c67',
#   'latitude': 48.85761567856468,
#   'longitude': 2.335831353037739,
#   'name': 'Institut de France',
#   'timestamp': '2022-05-13T00:18:02.206000Z'},
#  {'empty_slots': 17,
#   'extra': {'banking': False,
#    'ebikes': 4,
#    'last_updated': 1652397487,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 521393180,
#    'uid': '17008'},
#   'free_bikes': 6,
#   'id': 'd69e6c49d6c6695f57da105b15f25945',
#   'latitude': 48.8978765,
#   'longitude': 2.3230632,
#   'name': 'Porte Pouchet-Bessières',
#   'timestamp': '2022-05-13T00:18:01.623000Z'},
#  {'empty_slots': 3,
#   'extra': {'banking': False,
#    'ebikes': 10,
#    'last_updated': 1652397660,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 576188379,
#    'uid': '15112'},
#   'free_bikes': 21,
#   'id': 'cd91e4c9d707d0bebb4bd6677305110e',
#   'latitude': 48.838683941628375,
#   'longitude': 2.3110422492027287,
#   'name': 'Vigée-Lebrun - Anselme Payen',
#   'timestamp': '2022-05-13T00:18:00.976000Z'},
#  {'empty_slots': 37,
#   'extra': {'banking': True,
#    'ebikes': 0,
#    'last_updated': 1652397614,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 128882438,
#    'uid': '5020'},
#   'free_bikes': 1,
#   'id': 'fd8468cc02da7b7af7e2595ecb6732c7',
#   'latitude': 48.84906329950134,
#   'longitude': 2.3558086529374123,
#   'name': 'Institut du Monde Arabe - Saint-Germain',
#   'timestamp': '2022-05-13T00:18:00.660000Z'},
#  {'empty_slots': 18,
#   'extra': {'banking': True,
#    'ebikes': 3,
#    'last_updated': 1652397666,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 128915891,
#    'uid': '7025'},
#   'free_bikes': 14,
#   'id': 'b88622fa2683838b0565e7e0be139d6e',
#   'latitude': 48.856502977695634,
#   'longitude': 2.293178754328878,
#   'name': 'Octave Gréard - Tour Eiffel',
#   'timestamp': '2022-05-13T00:18:02.324000Z'},
#  {'empty_slots': 15,
#   'extra': {'banking': False,
#    'ebikes': 2,
#    'last_updated': 1652397485,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 82567101,
#    'uid': '31706'},
#   'free_bikes': 4,
#   'id': 'c6cd3ee1a82b246c5cb86035faa68d1a',
#   'latitude': 48.8629238005955,
#   'longitude': 2.415503561496735,
#   'name': 'Château - République',
#   'timestamp': '2022-05-13T00:18:03.531000Z'},
#  {'empty_slots': 26,
#   'extra': {'banking': False,
#    'ebikes': 5,
#    'last_updated': 1652397603,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 230877798,
#    'uid': '18107'},
#   'free_bikes': 7,
#   'id': 'f4eef18fca1505fcf19873c2f29849bd',
#   'latitude': 48.8847601,
#   'longitude': 2.3534657,
#   'name': 'Chartres - La Charbonnière',
#   'timestamp': '2022-05-13T00:18:00.670000Z'},
#  {'empty_slots': 30,
#   'extra': {'banking': True,
#    'ebikes': 0,
#    'last_updated': 1652397100,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 82379648,
#    'uid': '8036'},
#   'free_bikes': 1,
#   'id': 'e2671fe4b8fcccbbeeaaab7ef7ec9ff0',
#   'latitude': 48.87745567681383,
#   'longitude': 2.309694221419506,
#   'name': 'Lisbonne - Monceau',
#   'timestamp': '2022-05-13T00:18:00.368000Z'},
#  {'empty_slots': 16,
#   'extra': {'banking': False,
#    'ebikes': 0,
#    'last_updated': 1652397669,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 129021753,
#    'uid': '9028'},
#   'free_bikes': 0,
#   'id': '8d5e18ea3b29e7080dc930aeea34b28d',
#   'latitude': 48.88006587474148,
#   'longitude': 2.3310810327529907,
#   'name': 'Moncey - Blanche',
#   'timestamp': '2022-05-13T00:18:01.978000Z'},
#  {'empty_slots': 18,
#   'extra': {'banking': True,
#    'ebikes': 0,
#    'last_updated': 1652397610,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 129011497,
#    'uid': '9010'},
#   'free_bikes': 6,
#   'id': '27bde1c8b2832e7f88b2c34a98ec4404',
#   'latitude': 48.876719895109,
#   'longitude': 2.344393021853951,
#   'name': 'Rochechouart lamartine',
#   'timestamp': '2022-05-13T00:18:00.890000Z'},
#  {'empty_slots': 6,
#   'extra': {'banking': True,
#    'ebikes': 1,
#    'last_updated': 1652397663,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 35642049,
#    'uid': '10025'},
#   'free_bikes': 7,
#   'id': 'c112a52278dd51eab5e8e5714fe9ec8e',
#   'latitude': 48.87748519186726,
#   'longitude': 2.3660067468881607,
#   'name': 'Jemmapes - Ecluses Saint-Martin',
#   'timestamp': '2022-05-13T00:18:02.471000Z'},
#  {'empty_slots': 9,
#   'extra': {'banking': True,
#    'ebikes': 8,
#    'last_updated': 1652397625,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 50191171,
#    'uid': '19015'},
#   'free_bikes': 14,
#   'id': 'c923203a02ef3af397694f3c550a182c',
#   'latitude': 48.88917613743794,
#   'longitude': 2.3833653330802917,
#   'name': 'Thionville - Ourcq',
#   'timestamp': '2022-05-13T00:18:02.534000Z'},
#  {'empty_slots': 24,
#   'extra': {'banking': False,
#    'ebikes': 0,
#    'last_updated': 1652397369,
#    'renting': 0,
#    'returning': 0,
#    'station_id': 102290754,
#    'uid': '17012'},
#   'free_bikes': 0,
#   'id': '814ac1aadbc59ee28ada4b535b7693a0',
#   'latitude': 48.884161848716,
#   'longitude': 2.3220794311037,
#   'name': 'Mairie du 17ème',
#   'timestamp': '2022-05-13T00:18:03.522000Z'},
#  {'empty_slots': 38,
#   'extra': {'banking': False,
#    'ebikes': 6,
#    'last_updated': 1652397594,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 210740080,
#    'uid': '10107'},
#   'free_bikes': 11,
#   'id': 'bdb86d14e2bd6354e7aa1e7c7610acd4',
#   'latitude': 48.881949,
#   'longitude': 2.352339,
#   'name': 'Gare du Nord - Hôpital Lariboisière',
#   'timestamp': '2022-05-13T00:18:00.360000Z'},
#  {'empty_slots': 15,
#   'extra': {'banking': True,
#    'ebikes': 12,
#    'last_updated': 1652397626,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 129087587,
#    'uid': '17004'},
#   'free_bikes': 23,
#   'id': '03da963d41687bb7670f411eab74036c',
#   'latitude': 48.88896161855884,
#   'longitude': 2.322528975094376,
#   'name': 'Legendre - Clichy',
#   'timestamp': '2022-05-13T00:18:02.176000Z'},
#  {'empty_slots': 19,
#   'extra': {'banking': True,
#    'ebikes': 3,
#    'last_updated': 1652397582,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 213693511,
#    'uid': '19003'},
#   'free_bikes': 3,
#   'id': 'c503eafcf1cc851ff3626fe92a7d0f9a',
#   'latitude': 48.884492238407525,
#   'longitude': 2.3703941702842717,
#   'name': 'Quai de la Seine',
#   'timestamp': '2022-05-13T00:18:01.648000Z'},
#  {'empty_slots': 15,
#   'extra': {'banking': True,
#    'ebikes': 2,
#    'last_updated': 1652397347,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 95845524,
#    'uid': '10008'},
#   'free_bikes': 3,
#   'id': '226a0d91ca8223376402711fd4838710',
#   'latitude': 48.870702423554306,
#   'longitude': 2.358739863900845,
#   'name': "Cité Riverin - Château d'Eau",
#   'timestamp': '2022-05-13T00:18:03.055000Z'},
#  {'empty_slots': 35,
#   'extra': {'banking': True,
#    'ebikes': 0,
#    'last_updated': 1652397631,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 37815993,
#    'uid': '5018'},
#   'free_bikes': 1,
#   'id': '3cc2baaa200956820d5c8251505afd0e',
#   'latitude': 48.848225572724,
#   'longitude': 2.3502873256803,
#   'name': 'Mutualité',
#   'timestamp': '2022-05-13T00:18:00.526000Z'},
#  {'empty_slots': 31,
#   'extra': {'banking': False,
#    'ebikes': 0,
#    'last_updated': 1652397384,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 129014600,
#    'uid': '9022'},
#   'free_bikes': 0,
#   'id': 'e911d07b60f6a50248e5db3bb3e23668',
#   'latitude': 48.87334627510507,
#   'longitude': 2.337980867701675,
#   'name': 'Rossini - Laffitte',
#   'timestamp': '2022-05-13T00:18:02.535000Z'},
#  {'empty_slots': 30,
#   'extra': {'banking': False,
#    'ebikes': 8,
#    'last_updated': 1652397273,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 102324803,
#    'uid': '20042'},
#   'free_bikes': 8,
#   'id': '0ee885234307805f3d12d98e8c016fa1',
#   'latitude': 48.872010281270974,
#   'longitude': 2.392039597034455,
#   'name': 'Pyrénées - Emmery',
#   'timestamp': '2022-05-13T00:18:02.374000Z'},
#  {'empty_slots': 1,
#   'extra': {'banking': True,
#    'ebikes': 4,
#    'last_updated': 1652397542,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 912377361,
#    'uid': '12161'},
#   'free_bikes': 40,
#   'id': 'd40c98f308326f0b185cf41bb9a394ac',
#   'latitude': 48.84720845606067,
#   'longitude': 2.3861273378133774,
#   'name': 'Diderot - Reuilly',
#   'timestamp': '2022-05-13T00:18:00.494000Z'},
#  {'empty_slots': 6,
#   'extra': {'banking': True,
#    'ebikes': 10,
#    'last_updated': 1652397446,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 54000569,
#    'uid': '11027'},
#   'free_bikes': 31,
#   'id': 'acdd3a2005f56b2d29fe9be35e2a7b17',
#   'latitude': 48.86214784454763,
#   'longitude': 2.3772348091006275,
#   'name': 'Saint-Ambroise - Parmentier',
#   'timestamp': '2022-05-13T00:18:02.653000Z'},
#  {'empty_slots': 39,
#   'extra': {'banking': True,
#    'ebikes': 0,
#    'last_updated': 1652397426,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 80216231,
#    'uid': '17043'},
#   'free_bikes': 0,
#   'id': '768ddc2b2ca4a55976019dd0b9f6433d',
#   'latitude': 48.88022154052015,
#   'longitude': 2.2854680567979813,
#   'name': 'Belidor - Gouvion-Saint-Cyr',
#   'timestamp': '2022-05-13T00:18:00.232000Z'},
#  {'empty_slots': 0,
#   'extra': {'banking': True,
#    'ebikes': 10,
#    'last_updated': 1652397663,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 34742973,
#    'uid': '15056'},
#   'free_bikes': 25,
#   'id': '6ab04d33c2786fdee83912ebd000afe1',
#   'latitude': 48.836395736424116,
#   'longitude': 2.2784192115068436,
# ...
#    'uid': '23102'},
#   'free_bikes': 18,
#   'id': '0de24ad2ce21702099926b8763071b55',
#   'latitude': 48.824363561288756,
#   'longitude': 2.2131047397851944,
#   'name': 'Hôtel de Ville de Sèvres',
#   'timestamp': '2022-05-13T00:18:00.351000Z'},
#  {'empty_slots': 22,
#   'extra': {'banking': False,
#    'ebikes': 0,
#    'last_updated': 1652397612,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 1062797394,
#    'uid': '8117'},
#   'free_bikes': 0,
#   'id': '0808abab858d19e65b5ecb97039b67ab',
#   'latitude': 48.86922805264812,
#   'longitude': 2.3244211077690125,
#   'name': 'Place de la Madeleine - Royale',
#   'timestamp': '2022-05-13T00:18:00.206000Z'},
#  {'empty_slots': 15,
#   'extra': {'banking': False,
#    'ebikes': 14,
#    'last_updated': 1652397498,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 54000619,
#    'uid': '20022'},
#   'free_bikes': 16,
#   'id': 'e20b889c063c1bad353bc706ef645ab6',
#   'latitude': 48.864707139122984,
#   'longitude': 2.408344637349607,
#   'name': 'Porte de Bagnolet',
#   'timestamp': '2022-05-13T00:18:02.878000Z'},
#  {'empty_slots': 6,
#   'extra': {'banking': True,
#    'ebikes': 16,
#    'last_updated': 1652397632,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 43247738,
#    'uid': '18026'},
#   'free_bikes': 27,
#   'id': 'cd5327b63663bffded353199712296fa',
#   'latitude': 48.89299462568024,
#   'longitude': 2.340144887566567,
#   'name': 'Ruisseau - Ordener',
#   'timestamp': '2022-05-13T00:18:00.593000Z'},
#  {'empty_slots': 35,
#   'extra': {'banking': True,
#    'ebikes': 0,
#    'last_updated': 1652397553,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 82332239,
#    'uid': '5007'},
#   'free_bikes': 0,
#   'id': '9d18733666f1a40149f7471390185296',
#   'latitude': 48.848904447989405,
#   'longitude': 2.3473486304283147,
#   'name': 'Ecoles - Carmes',
#   'timestamp': '2022-05-13T00:18:00.665000Z'},
#  {'empty_slots': 13,
#   'extra': {'banking': True,
#    'ebikes': 18,
#    'last_updated': 1652397616,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 75525462,
#    'uid': '14026'},
#   'free_bikes': 31,
#   'id': '0aff2f4aa9975ae7f3379f273cec4083',
#   'latitude': 48.83005755305626,
#   'longitude': 2.3232302069664006,
#   'name': 'Plantes - Moulin Vert',
#   'timestamp': '2022-05-13T00:18:00.811000Z'},
#  {'empty_slots': 27,
#   'extra': {'banking': False,
#    'ebikes': 2,
#    'last_updated': 1652397358,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 15462861,
#    'uid': '16105'},
#   'free_bikes': 3,
#   'id': '9d5e8812bab913b5ffae948cf4730781',
#   'latitude': 48.870809428669546,
#   'longitude': 2.281149007691853,
#   'name': 'Crevaux - Bugeaud',
#   'timestamp': '2022-05-13T00:18:01.215000Z'},
#  {'empty_slots': 21,
#   'extra': {'banking': False,
#    'ebikes': 1,
#    'last_updated': 1652397349,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 49474389,
#    'uid': '8103'},
#   'free_bikes': 2,
#   'id': '1067e1bd44428676a13371f6b7ab121e',
#   'latitude': 48.87393521240818,
#   'longitude': 2.3064258322119713,
#   'name': 'Artois - Berri',
#   'timestamp': '2022-05-13T00:18:00.714000Z'},
#  {'empty_slots': 0,
#   'extra': {'banking': True,
#    'ebikes': 2,
#    'last_updated': 1652397471,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 15308712,
#    'uid': '11112'},
#   'free_bikes': 22,
#   'id': 'c9a014d11040b1861c6e85efbb832ed8',
#   'latitude': 48.85428437993525,
#   'longitude': 2.384767457842827,
#   'name': 'Jules Vallès - Charonne',
#   'timestamp': '2022-05-13T00:18:02.031000Z'},
#  {'empty_slots': 47,
#   'extra': {'banking': True,
#    'ebikes': 2,
#    'last_updated': 1652397677,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 82554449,
#    'uid': '16036'},
#   'free_bikes': 12,
#   'id': '29f54fb4923c0fbdedb3fa4604021806',
#   'latitude': 48.84524763511433,
#   'longitude': 2.2569015249609947,
#   'name': 'Porte Molitor',
#   'timestamp': '2022-05-13T00:18:00.856000Z'},
#  {'empty_slots': 0,
#   'extra': {'banking': False,
#    'ebikes': 11,
#    'last_updated': 1652397659,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 39535340,
#    'uid': '42505'},
#   'free_bikes': 30,
#   'id': 'd3b3781c33d6911a2b9500deaae8f33b',
#   'latitude': 48.8155839183714,
#   'longitude': 2.3505029082298283,
#   'name': 'Charles Frérot - Albert Guilpin',
#   'timestamp': '2022-05-13T00:18:00.342000Z'},
#  {'empty_slots': 1,
#   'extra': {'banking': True,
#    'ebikes': 7,
#    'last_updated': 1652397592,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 1057758764,
#    'uid': '15128'},
#   'free_bikes': 33,
#   'id': '2fb8cc6d815cc5d8c44e833b84caacc8',
#   'latitude': 48.8340107632249,
#   'longitude': 2.289516180753708,
#   'name': 'Cadix - Hameau',
#   'timestamp': '2022-05-13T00:18:03.381000Z'},
#  {'empty_slots': 27,
#   'extra': {'banking': True,
#    'ebikes': 3,
#    'last_updated': 1652397657,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 101008598,
#    'uid': '12036'},
#   'free_bikes': 14,
#   'id': '6bc6f2d8fdc3834725d146dcf9357fda',
#   'latitude': 48.84030274499962,
#   'longitude': 2.394630398715453,
#   'name': 'Reuilly - Place Felix Eboue',
#   'timestamp': '2022-05-13T00:18:00.432000Z'},
#  {'empty_slots': 8,
#   'extra': {'banking': True,
#    'ebikes': 11,
#    'last_updated': 1652397614,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 1057373549,
#    'uid': '26004'},
#   'free_bikes': 14,
#   'id': '1c07dff207e7a45b0425b256837b96df',
#   'latitude': 48.919898633572764,
#   'longitude': 2.31458459136273,
#   'name': 'Gare RER les Grésillons',
#   'timestamp': '2022-05-13T00:18:03.299000Z'},
#  {'empty_slots': 31,
#   'extra': {'banking': False,
#    'ebikes': 0,
#    'last_updated': 1652397666,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 66491388,
#    'uid': '8044'},
#   'free_bikes': 1,
#   'id': '7ad11b6e7ea15032c55a328e0389d49d',
#   'latitude': 48.87836138361425,
#   'longitude': 2.305254448220567,
#   'name': 'Alfred de Vigny - Place du Général Brocard',
#   'timestamp': '2022-05-13T00:18:01.562000Z'},
#  {'empty_slots': 31,
#   'extra': {'banking': True,
#    'ebikes': 2,
#    'last_updated': 1652397662,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 128841079,
#    'uid': '1020'},
#   'free_bikes': 4,
#   'id': 'f433a4e9e21c3002ad16356b3f6736e5',
#   'latitude': 48.866143390992,
#   'longitude': 2.3251800647137,
#   'name': 'Cambon - Rivoli',
#   'timestamp': '2022-05-13T00:18:01.883000Z'},
#  {'empty_slots': 29,
#   'extra': {'banking': True,
#    'ebikes': 0,
#    'last_updated': 1652397508,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 54000555,
#    'uid': '8031'},
#   'free_bikes': 2,
#   'id': '8450f57ac206a32b85baa5d454366148',
#   'latitude': 48.869689856852,
#   'longitude': 2.3107324540615,
#   'name': 'Jean Mermoz - Champs-Elysées',
#   'timestamp': '2022-05-13T00:18:00.491000Z'},
#  {'empty_slots': 25,
#   'extra': {'banking': False,
#    'ebikes': 3,
#    'last_updated': 1652397488,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 54000570,
#    'uid': '12015'},
#   'free_bikes': 11,
#   'id': '85eddb44cbdcb7673baa653c5577a5e5',
#   'latitude': 48.846821681548,
#   'longitude': 2.4001130461693,
#   'name': 'Place de la Nation - Picpus',
#   'timestamp': '2022-05-13T00:18:02.656000Z'},
#  {'empty_slots': 11,
#   'extra': {'banking': True,
#    'ebikes': 7,
#    'last_updated': 1652397607,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 653089942,
#    'uid': '18139'},
#   'free_bikes': 10,
#   'id': '916abb00296671bf40a0857fbe6e9c09',
#   'latitude': 48.89543299733937,
#   'longitude': 2.3530178144574165,
#   'name': 'Poissonniers - Championnet',
#   'timestamp': '2022-05-13T00:18:03.056000Z'},
#  {'empty_slots': 38,
#   'extra': {'banking': True,
#    'ebikes': 2,
#    'last_updated': 1652397360,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 38407,
#    'uid': '16012'},
#   'free_bikes': 2,
#   'id': 'f46cb679b494cb6b960dcf9a7b7487b7',
#   'latitude': 48.86877849178477,
#   'longitude': 2.274354539176829,
#   'name': 'Flandrin - Longchamp',
#   'timestamp': '2022-05-13T00:18:01.922000Z'},
#  {'empty_slots': 33,
#   'extra': {'banking': True,
#    'ebikes': 0,
#    'last_updated': 1652397584,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 220504949,
#    'uid': '1006'},
#   'free_bikes': 0,
#   'id': '6a2afbbf8bede56b4edb7c3ebade0e6c',
#   'latitude': 48.8626302,
#   'longitude': 2.3498075,
#   'name': 'Grande Truanderie - Saint-Denis',
#   'timestamp': '2022-05-13T00:18:00.363000Z'},
#  {'empty_slots': 21,
#   'extra': {'banking': False,
#    'ebikes': 5,
#    'last_updated': 1652397672,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 27296946,
#    'uid': '19110'},
#   'free_bikes': 8,
#   'id': 'c3a5c7dc8528197bcf74a69f8c3a9f85',
#   'latitude': 48.89876016219984,
#   'longitude': 2.375325746834278,
#   'name': 'Square Claude Bernard',
#   'timestamp': '2022-05-13T00:18:00.427000Z'},
#  {'empty_slots': 14,
#   'extra': {'banking': False,
#    'ebikes': 0,
#    'last_updated': 1652397394,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 7295,
#    'uid': '6010'},
#   'free_bikes': 0,
#   'id': '38787182226b5ab865aadc3b85851db5',
#   'latitude': 48.841739161230905,
#   'longitude': 2.331552216736739,
#   'name': 'Chevreuse - Montparnasse',
#   'timestamp': '2022-05-13T00:18:03.045000Z'},
#  {'empty_slots': 14,
#   'extra': {'banking': True,
#    'ebikes': 12,
#    'last_updated': 1652397503,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 653143563,
#    'uid': '22201'},
#   'free_bikes': 16,
#   'id': '27d5bbf1a7a5546c90998877e29784d8',
#   'latitude': 48.79722273833844,
#   'longitude': 2.302115857601166,
#   'name': 'Henri Ravera - Gabriel Péri',
#   'timestamp': '2022-05-13T00:18:00.841000Z'},
#  {'empty_slots': 29,
#   'extra': {'banking': True,
#    'ebikes': 1,
#    'last_updated': 1652397571,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 443153677,
#    'uid': '3008'},
#   'free_bikes': 4,
#   'id': '88251df4ad9261e6c17a643408e06f51',
#   'latitude': 48.8601346,
#   'longitude': 2.3611206,
#   'name': 'Perle - Vieille du Temple',
#   'timestamp': '2022-05-13T00:18:03.222000Z'},
#  {'empty_slots': 53,
#   'extra': {'banking': True,
#    'ebikes': 1,
#    'last_updated': 1652397665,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 41464928,
#    'uid': '15008'},
#   'free_bikes': 8,
#   'id': '9c3824733e3c2b8c8abdd07679ab5659',
#   'latitude': 48.8447677,
#   'longitude': 2.3110086,
#   'name': 'Sèvres - Lecourbe',
#   'timestamp': '2022-05-13T00:18:01.666000Z'},
#  {'empty_slots': 58,
#   'extra': {'banking': True,
#    'ebikes': 3,
#    'last_updated': 1652397480,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 66505510,
#    'uid': '5015'},
#   'free_bikes': 4,
#   'id': 'f5a5400dea698cd099e91777ad0e887d',
#   'latitude': 48.841508690388835,
#   'longitude': 2.350066713988781,
#   'name': 'Epée de Bois - Mouffetard',
#   'timestamp': '2022-05-13T00:18:00.694000Z'},
#  {'empty_slots': 10,
#   'extra': {'banking': True,
#    'ebikes': 7,
#    'last_updated': 1652397585,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 66491391,
#    'uid': '10032'},
#   'free_bikes': 21,
#   'id': '1e4736707abc68279a370203e602ec55',
#   'latitude': 48.87285913900304,
#   'longitude': 2.370071706985146,
#   'name': 'Claude Vellefaux - Hôpital Saint-Louis',
#   'timestamp': '2022-05-13T00:18:01.573000Z'},
#  {'empty_slots': 14,
#   'extra': {'banking': True,
#    'ebikes': 4,
#    'last_updated': 1652397435,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 1062256852,
#    'uid': '48004'},
#   'free_bikes': 5,
#   'id': 'a94f709a498fb6af00283b70ac8273d4',
#   'latitude': 48.78909814728443,
#   'longitude': 2.368387877941132,
#   'name': 'Maxime Gorki - Louis Aragon',
#   'timestamp': '2022-05-13T00:18:00.239000Z'},
#  {'empty_slots': 1,
#   'extra': {'banking': False,
#    'ebikes': 5,
#    'last_updated': 1652397605,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 1062245074,
#    'uid': '45002'},
#   'free_bikes': 24,
#   'id': '116e8d9a96e2a9b431b6f1fa248ebcd8',
#   'latitude': 48.820029010376956,
#   'longitude': 2.4846760556101803,
#   'name': 'Roger Salengro - Général de Gaulle',
#   'timestamp': '2022-05-13T00:18:01.321000Z'},
#  {'empty_slots': 35,
#   'extra': {'banking': True,
#    'ebikes': 0,
#    'last_updated': 1652397584,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 201923447,
#    'uid': '16042'},
#   'free_bikes': 2,
#   'id': '1c46a54dfc28d763c1b51854e1a6d6d4',
#   'latitude': 48.83750862621299,
#   'longitude': 2.2577651962637906,
#   'name': 'Murat - Porte de Saint-Cloud',
#   'timestamp': '2022-05-13T00:18:02.564000Z'},
#  {'empty_slots': 41,
#   'extra': {'banking': True,
#    'ebikes': 1,
#    'last_updated': 1652397309,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 38060,
#    'uid': '15001'},
#   'free_bikes': 2,
#   'id': '446c463f3ddf30b55077389e71756269',
#   'latitude': 48.843827994314886,
#   'longitude': 2.3225811123847966,
#   'name': 'Gare Montparnasse - Arrivée',
#   'timestamp': '2022-05-13T00:18:01.684000Z'},
#  {'empty_slots': 52,
#   'extra': {'banking': False,
#    'ebikes': 0,
#    'last_updated': 1644500615,
#    'renting': 0,
#    'returning': 0,
#    'station_id': 265201872,
#    'uid': '4006'},
#   'free_bikes': 0,
#   'id': 'c809de54c74118121dda515b88cc8cd7',
#   'latitude': 48.8478103,
#   'longitude': 2.3659356,
#   'name': 'Bourdon - Pont Morland',
#   'timestamp': '2022-05-13T00:18:00.606000Z'},
#  {'empty_slots': 15,
#   'extra': {'banking': True,
#    'ebikes': 10,
#    'last_updated': 1652397562,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 653144717,
#    'uid': '44014'},
#   'free_bikes': 10,
#   'id': 'cef647062b0306bc184c430223a2155e',
#   'latitude': 48.774703,
#   'longitude': 2.373685,
#   'name': 'Camille Risch - Paul Armangot',
#   'timestamp': '2022-05-13T00:18:00.899000Z'},
#  {'empty_slots': 17,
#   'extra': {'banking': True,
#    'ebikes': 15,
#    'last_updated': 1652397636,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 42275164,
#    'uid': '12037'},
#   'free_bikes': 18,
#   'id': '302b7e83d0ff4a0ca62b47b683cf116f',
#   'latitude': 48.8395385,
#   'longitude': 2.3972516,
#   'name': 'Reuilly - Daumesnil',
#   'timestamp': '2022-05-13T00:18:01.137000Z'},
#  {'empty_slots': 32,
#   'extra': {'banking': True,
#    'ebikes': 2,
#    'last_updated': 1652397559,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 30730,
#    'uid': '20001'},
#   'free_bikes': 3,
#   'id': '7ee5e0361df559e7d3e154be71e7f316',
#   'latitude': 48.848364667777,
#   'longitude': 2.3997623859813,
#   'name': 'Place de la Nation - Charonne',
#   'timestamp': '2022-05-13T00:18:02.118000Z'},
#  {'empty_slots': 1,
#   'extra': {'banking': False,
#    'ebikes': 9,
#    'last_updated': 1652397447,
#    'renting': 1,
#    'returning': 1,
#    'station_id': 97824043,
#    'uid': '47003'},
#   'free_bikes': 18,
#   'id': 'dd3c11f52763903894a4651556d7f448',
#   'latitude': 48.809932980484355,
#   'longitude': 2.443288456496946,
#   'name': 'Charentonneau - Maisons Alfort',
#   'timestamp': '2022-05-13T00:18:00.803000Z'},
#  {'empty_slots': 10,
#   'extra': {'banking': True,
#    'ebikes': 1,
#    'last_updated': 1652397574,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 66491379,
#    'uid': '18004'},
#   'free_bikes': 1,
#   'id': '0e2b638a169bf04e728a4a023014129a',
#   'latitude': 48.884542726149725,
#   'longitude': 2.3386867716908455,
#   'name': 'Place des Abbesses',
#   'timestamp': '2022-05-13T00:18:01.547000Z'},
#  {'empty_slots': 14,
#   'extra': {'banking': True,
#    'ebikes': 9,
#    'last_updated': 1652397384,
#    'payment': ['creditcard'],
#    'renting': 1,
#    'returning': 1,
#    'station_id': 39169029,
#    'uid': '20034'},
#   'free_bikes': 10,
#   'id': '282ed329db5ce418efeb668f71ca6e80',
#   'latitude': 48.86854239566069,
#   'longitude': 2.3897721245884895,
#   'name': 'Sorbier - Ménilmontant',
#   'timestamp': '2022-05-13T00:18:00.746000Z'},
#  ...]

# %%
def get_available_stations(city = "Paris"):
    '''
    Takes in the city name and returns a pandas dataframe containing information about the city
    Default city name is Paris
    '''
    station_info = get_stations_info(city)
    
    station_list = []
    for info in station_info:

        a_dict = {
            'Station Name': info['name'],
            'empty_slots' : info['empty_slots'],
            'free_bikes' : info['free_bikes'],
            'ebikes' : info['extra']['ebikes'],
            'payment': ', '.join(info['extra']['payment']) if info['extra']['banking'] else "No" ,
            'latitude' : info['latitude'],
            'longitude' : info['longitude'],
            'timestamp' : info['timestamp'],
            'Unique ID': info['extra']['uid'],
        }
        station_list.append(a_dict)
        
    return pd.DataFrame(station_list)

# %%
get_available_stations(city = "Paris").sample(5)
# Out:
#                     Station Name  empty_slots  free_bikes  ebikes     payment  \
# 1399  Bichat - Grange aux Belles           18          10       3  creditcard
# 869         Halles - Bourdonnais           19           1       0  creditcard
# 1275        Champeaux - Gallieni           37           9       7  creditcard
# 460              Milton - Manuel           14           8       2          No
# 350             Ouest - Château            19           4       3  creditcard
#
#        latitude  longitude                    timestamp Unique ID
# 1399  48.873688   2.365015  2022-05-13T00:18:01.761000Z     10202
# 869   48.860449   2.346016  2022-05-13T00:18:01.087000Z      1021
# 1275  48.864459   2.416178  2022-05-13T00:18:01.992000Z     31705
# 460   48.878249   2.341181  2022-05-13T00:18:01.674000Z      9115
# 350   48.836173   2.319392  2022-05-13T00:18:01.897000Z     14034

# %%
ACCESS_MAP_TOKEN = "pk.eyJ1IjoiYWpvc2VndW4iLCJhIjoiY2t3NnVlZXVrMDIyZjJ1cW1wY2lraGpscSJ9.iPudHyKbx7WXazNrcPH1rA"

# %%
def show_map(station_data):
    '''
    Takes in data of the station info in a dataframe format
    
    Shows a map
    '''

    ## Get the current date and time
    current_date = pd.to_datetime(station_data['timestamp'][0]).strftime('%a %d %B, %Y at %H:%M')
        
    map_title = 'Map Showing Number of Bikes in {} at {}'.format(city, current_date)


    # Get access token from ploty
    px.set_mapbox_access_token(ACCESS_MAP_TOKEN)

    fig = px.scatter_mapbox(station_data, lat="latitude", lon="longitude", hover_name="Station Name", color="free_bikes",
                            hover_data=["empty_slots", "free_bikes", "ebikes", "payment"],
                             title=map_title, 
                              color_continuous_scale=px.colors.sequential.Plasma, size_max=20,zoom=12)


    fig.show()

# %%
def get_location_data(this_station_data):
    '''
    This method requests input from the biker and returns either of the following 
    - Location data a single location is found for the input
    - No data if the entry is quit  
    
    It displays a list of locations if the input matches more than one location
    - It requests the biker to input the full name of the location from the displayed list
    '''
    
    while True:
        station_name = input("Enter the location you are interested in (quit to exit): ")
        if station_name.strip().lower() == 'quit':
            print("Exiting...")
            return pd.DataFrame(columns = ["Station data is not available"])
#             return None
            
        requested_station_data = this_station_data[this_station_data["name"].map(lambda name: station_name.lower() in name.lower())]

        if len(requested_station_data.index) == 1:
            return requested_station_data
        
        elif requested_station_data.empty:
            print("Error: No data found for the location. Enter a valid location")           
            continue
        else:
            print("Too many values, kindly enter the station full name:")
            for each_data in requested_station_data.index:
                 print(requested_station_data['name'][each_data])
            continue

# %%
live_city_data = get_available_stations("Paris")
show_map(live_city_data)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="42a1da18-b10c-46f3-a4cb-f717a3130c35" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("42a1da18-b10c-46f3-a4cb-f717a3130c35")) {                    Plotly.newPlot(                        "42a1da18-b10c-46f3-a4cb-f717a3130c35",                        [{"customdata":[[21,14,1,"No"],[53,2,1,"creditcard"],[30,4,3,"creditcard"],[16,1,1,"creditcard"],[15,6,4,"creditcard"],[1,19,9,"No"],[1,27,4,"No"],[56,2,2,"creditcard"],[45,0,0,"creditcard"],[26,13,9,"creditcard"],[24,10,4,"creditcard"],[29,28,0,"creditcard"],[16,1,1,"creditcard"],[23,2,1,"creditcard"],[17,2,2,"creditcard"],[17,0,0,"No"],[16,6,0,"creditcard"],[13,3,1,"No"],[13,17,7,"No"],[1,25,19,"No"],[7,40,17,"creditcard"],[5,19,6,"creditcard"],[15,6,6,"creditcard"],[28,20,4,"creditcard"],[20,3,2,"creditcard"],[44,1,0,"creditcard"],[6,13,12,"No"],[16,1,0,"No"],[14,28,1,"creditcard"],[18,1,1,"creditcard"],[1,49,22,"No"],[5,65,1,"creditcard"],[31,4,2,"creditcard"],[25,8,2,"creditcard"],[25,17,8,"creditcard"],[14,6,4,"No"],[29,9,7,"No"],[15,1,1,"No"],[1,19,1,"creditcard"],[34,6,4,"No"],[10,21,6,"creditcard"],[1,29,6,"creditcard"],[29,12,0,"No"],[27,2,1,"creditcard"],[13,13,8,"No"],[15,9,2,"creditcard"],[13,5,5,"No"],[5,18,15,"No"],[18,7,3,"No"],[22,3,3,"creditcard"],[3,19,8,"No"],[31,1,1,"creditcard"],[9,31,29,"creditcard"],[15,10,6,"No"],[38,0,0,"No"],[10,7,3,"No"],[61,2,0,"creditcard"],[13,6,4,"No"],[18,0,0,"No"],[3,11,6,"creditcard"],[12,22,1,"creditcard"],[22,0,0,"No"],[5,20,18,"No"],[26,14,2,"creditcard"],[24,1,0,"creditcard"],[15,7,6,"No"],[18,2,2,"No"],[16,9,5,"No"],[24,0,0,"No"],[11,37,17,"creditcard"],[28,1,1,"No"],[9,8,2,"creditcard"],[20,1,1,"No"],[18,2,2,"creditcard"],[13,6,3,"No"],[12,14,8,"No"],[4,57,5,"No"],[40,1,1,"creditcard"],[43,2,1,"creditcard"],[5,28,18,"creditcard"],[19,4,1,"No"],[11,3,1,"creditcard"],[19,1,0,"creditcard"],[13,1,0,"No"],[23,5,3,"creditcard"],[46,2,0,"creditcard"],[26,1,1,"No"],[16,23,1,"creditcard"],[10,2,2,"creditcard"],[23,2,2,"creditcard"],[33,1,0,"creditcard"],[8,8,8,"No"],[55,4,2,"creditcard"],[15,0,0,"creditcard"],[17,6,4,"No"],[3,21,10,"No"],[37,1,0,"creditcard"],[18,14,3,"creditcard"],[15,4,2,"No"],[26,7,5,"No"],[30,1,0,"creditcard"],[16,0,0,"No"],[18,6,0,"creditcard"],[6,7,1,"creditcard"],[9,14,8,"creditcard"],[24,0,0,"No"],[38,11,6,"No"],[15,23,12,"creditcard"],[19,3,3,"creditcard"],[15,3,2,"creditcard"],[35,1,0,"creditcard"],[31,0,0,"No"],[30,8,8,"No"],[1,40,4,"creditcard"],[6,31,10,"creditcard"],[39,0,0,"creditcard"],[0,25,10,"creditcard"],[13,4,4,"No"],[13,10,2,"creditcard"],[31,1,1,"No"],[3,41,11,"creditcard"],[21,12,8,"No"],[16,10,9,"No"],[23,26,0,"creditcard"],[7,15,7,"creditcard"],[3,14,2,"creditcard"],[3,24,12,"No"],[8,4,1,"creditcard"],[0,11,1,"creditcard"],[46,6,3,"No"],[37,1,1,"No"],[50,6,2,"No"],[13,11,10,"No"],[13,4,3,"No"],[16,13,0,"No"],[39,1,0,"creditcard"],[0,32,6,"creditcard"],[10,24,7,"No"],[14,3,0,"No"],[50,1,1,"creditcard"],[46,11,2,"creditcard"],[63,5,3,"creditcard"],[33,4,3,"creditcard"],[16,5,2,"creditcard"],[8,26,18,"creditcard"],[7,22,15,"creditcard"],[15,0,0,"No"],[8,14,8,"creditcard"],[60,2,1,"creditcard"],[8,17,8,"No"],[45,3,1,"No"],[5,19,19,"No"],[6,9,9,"No"],[4,14,9,"No"],[49,6,3,"creditcard"],[9,21,18,"creditcard"],[1,37,20,"creditcard"],[11,13,2,"creditcard"],[39,24,3,"No"],[0,33,26,"creditcard"],[19,7,7,"No"],[11,7,0,"No"],[8,12,8,"No"],[12,16,5,"No"],[26,6,4,"No"],[13,3,1,"creditcard"],[1,24,9,"No"],[13,2,2,"No"],[0,31,16,"creditcard"],[1,17,7,"No"],[23,19,14,"creditcard"],[10,9,8,"creditcard"],[0,19,1,"No"],[2,31,0,"creditcard"],[25,8,4,"creditcard"],[29,8,3,"creditcard"],[16,0,0,"No"],[0,24,1,"No"],[43,4,2,"creditcard"],[18,2,2,"No"],[23,5,3,"No"],[11,16,6,"No"],[23,0,0,"No"],[19,11,5,"creditcard"],[5,15,14, ...

# %%
live_city_data
# Out:
#                                   Station Name  empty_slots  free_bikes  \
# 0                Benjamin Godard - Victor Hugo           21          14
# 1           André Mazet - Saint-André des Arts           53           2
# 2              Faubourg Du Temple - Republique           30           4
# 3                       Beaux-Arts - Bonaparte           16           1
# 4                           Toudouze - Clauzel           15           6
# ...                                        ...          ...         ...
# 1423                 Paul Valery - Victor Hugo           31           4
# 1424  Faubourg St-Antoine - Place de la Nation           13           3
# 1425    Quai de Sèvres - Manufacture Nationale           28           0
# 1426                     Gare RER les Ardoines            0          48
# 1427                Roland Garros - Jean Bouin           20           8
#
#       ebikes     payment   latitude  longitude                    timestamp  \
# 0          1          No  48.865983   2.275725  2022-05-13T00:18:03.514000Z
# 1          1  creditcard  48.853756   2.339096  2022-05-13T00:18:03.381000Z
# 2          3  creditcard  48.867872   2.364898  2022-05-13T00:18:00.418000Z
# 3          1  creditcard  48.856452   2.334852  2022-05-13T00:18:00.755000Z
# 4          4  creditcard  48.879296   2.337360  2022-05-13T00:18:00.823000Z
# ...      ...         ...        ...        ...                          ...
# 1423       4          No  48.871374   2.288713  2022-05-13T00:18:00.451000Z
# 1424       3          No  48.848773   2.393606  2022-05-13T00:18:00.882000Z
# 1425       0  creditcard  48.829135   2.223762  2022-05-13T00:18:00.726000Z
# 1426      44  creditcard  48.783856   2.407909  2022-05-13T00:18:00.343000Z
# 1427       7          No  48.809461   2.285320  2022-05-13T00:18:02.375000Z
#
#      Unique ID
# 0        16107
# 1         6015
# 2        11037
# 3         6021
# 4         9020
# ...        ...
# 1423     16104
# 1424     11201
# 1425     23104
# 1426     44009
# 1427     23204
#
# [1428 rows x 9 columns]

# %%
def show_pie_chart(live_data, station_name):

    '''
    Takes in the live data (Pandas dataframe ) and requested station name
    Shows a pie chart of the information
    Returns nothing
    '''
    
    if live_data.empty:
      print("Error: Station data is not available!")
      return None

    requested_station_data = live_data[live_data["Station Name"].map(lambda name: station_name.lower() in name.lower())]
    
    current_date = pd.to_datetime(live_data['timestamp'][0]).strftime('%a %d %B, %Y at %H:%M')

    title = "Bike information for: {0} - Payment type - {1} at {2}".format(
                    requested_station_data["Station Name"].to_string(index=False),
                    requested_station_data["payment"].to_string(index=False),
                    current_date)
    
    data = [int(requested_station_data["empty_slots"]), 
            int(requested_station_data["free_bikes"]), 
            int(requested_station_data["ebikes"]),
             ]

    fig = px.pie(data, values=data, names=["Empty Slots", "Free Bikes", "ebikes"], hole=.3,
                title = title)
    

    fig.update_traces(textposition='inside', textinfo='value+label')

    fig.show()

# %%
live_city_data = get_available_stations("Paris")
show_pie_chart(live_city_data, "Gare RER les Ardoines")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="1c7c6819-e538-4f1c-adba-325cb0789712" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1c7c6819-e538-4f1c-adba-325cb0789712")) {                    Plotly.newPlot(                        "1c7c6819-e538-4f1c-adba-325cb0789712",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.3,"hovertemplate":"label=%{label}<br>value=%{value}<extra></extra>","labels":["Empty Slots","Free Bikes","ebikes"],"legendgroup":"","name":"","showlegend":true,"values":[0,48,44],"type":"pie","textinfo":"value+label","textposition":"inside"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{" ...

# %%
def show_bar_chart(live_data, station_name):

    '''
    Takes in the live data (Pandas dataframe ) and requested station name
    Shows a bar chart of the information
    Returns nothing
    '''
    
    if live_data.empty:
        print("Error: Station data is not available!")
        return None

    requested_station_data = live_data[live_data["Station Name"].map(lambda name: station_name.lower() in name.lower())]
    
    current_date = pd.to_datetime(live_data['timestamp'][0]).strftime('%a %d %B, %Y at %H:%M')

    title = "Bike information for: {0} - Payment type - {1} at {2}".format(
                    requested_station_data["Station Name"].to_string(index=False),
                    requested_station_data["payment"].to_string(index=False),
                    current_date)
    
    data = [int(requested_station_data["empty_slots"]), 
            int(requested_station_data["free_bikes"]), 
            int(requested_station_data["ebikes"]),
             ]
    
    fig = px.bar(data,  x=["Empty Slots", "Free Bikes", "ebikes"], y = data, color = data,
                 labels={'y':'Number of Bikes', 'x':""}, title = title                
                 )
    fig.show()

# %%
live_city_data = get_available_stations("Paris")
show_bar_chart(live_city_data, "Gare RER les Ardoines")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="5819b2c1-9976-4286-bb9e-5d47b157f73c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5819b2c1-9976-4286-bb9e-5d47b157f73c")) {                    Plotly.newPlot(                        "5819b2c1-9976-4286-bb9e-5d47b157f73c",                        [{"alignmentgroup":"True","hovertemplate":"=%{x}<br>Number of Bikes=%{y}<br>color=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[0,48,44],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Empty Slots","Free Bikes","ebikes"],"xaxis":"x","y":[0,48,44],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"sca ...
