# %% [markdown]
# [Reference](https://medium.com/geekculture/how-to-use-seaborn-in-python-to-visualize-the-fmri-dataset-ae89381157ea)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'tips', 'titanic']

# %%
fmri = sns.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
fmri.describe()
# Out:
#          timepoint       signal
# count  1064.000000  1064.000000
# mean      9.000000     0.003540
# std       5.479801     0.093930
# min       0.000000    -0.255486
# 25%       4.000000    -0.046070
# 50%       9.000000    -0.013653
# 75%      14.000000     0.024293
# max      18.000000     0.564985

# %%
fmri.columns = ['Subject','Timepoint','Event','Region','Signal']
fmri=fmri.set_index('Subject')
fmri.replace({'frontal':'Frontal','parietal':'Parietal','cue':'Cue',
              'stim':'Stim'},inplace=True)
fmri.head()
# Out:
#          Timepoint Event    Region    Signal
# Subject
# s13             18  Stim  Parietal -0.017552
# s5              14  Stim  Parietal -0.080883
# s12             18  Stim  Parietal -0.081033
# s11             18  Stim  Parietal -0.046134
# s10             18  Stim  Parietal -0.037970

# %%
sns.relplot(x="Timepoint", y='Signal', hue="Region", style="Event",
            palette="ch:rot=-.25,hue=1,light=.75",
            dashes=False, markers=True, kind="line", data=fmri);

# %%
sns.boxplot(x='Timepoint',y='Signal',hue="Region",
            data=fmri,palette='ch:rot=-.25,hue=1,light=.75')

# %%
sns.set(style='whitegrid')
sns.swarmplot(x='Timepoint',y='Signal',hue="Region",
              data=fmri,palette='ch:rot=-.25,hue=1,light=.75')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 71.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 69.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 51.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 42.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.lmplot(x='Timepoint',y='Signal',hue="Region",
           col="Event",row="Region",data=fmri)
