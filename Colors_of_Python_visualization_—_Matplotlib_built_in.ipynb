# %% [markdown]
# [Reference](https://towardsdev.com/colors-of-python-visualization-matplotlib-built-in-23a8a0a49ac2)

# %%
# From official site
import matplotlib.pyplot as plt
import numpy as np
import matplotlib

t = np.linspace(0.0, 2.0, 201)
s = np.sin(2 * np.pi * t)

# 1) RGB tuple:
fig, ax = plt.subplots(facecolor=(.18, .31, .31),figsize=(10,5))
# 2) hex string:
ax.set_facecolor('#eafff5')
# 3) gray level string:
ax.set_title('Voltage vs. time chart', color='0.7')
# 4) single letter color string
ax.set_xlabel('time (s)', color='c')
# 5) a named color:
ax.set_ylabel('voltage (mV)', color='peachpuff')
# 6) a named xkcd color:
ax.plot(t, s, 'xkcd:crimson')
# 7) Cn notation:
ax.plot(t, .7*s, color='C4', linestyle='--')
# 8) tab notation:
ax.tick_params(labelcolor='tab:orange')
plt.show()

# %%
def plot_colors(colors, r=0):
    plt.bar(list(colors.keys()), [1]*len(colors), color=list(colors.keys()))
    plt.xticks(rotation=r)

plot_colors(matplotlib.colors.BASE_COLORS)

# %%
matplotlib.colors.TABLEAU_COLORS
# Out:
# {'tab:blue': '#1f77b4',
#  'tab:orange': '#ff7f0e',
#  'tab:green': '#2ca02c',
#  'tab:red': '#d62728',
#  'tab:purple': '#9467bd',
#  'tab:brown': '#8c564b',
#  'tab:pink': '#e377c2',
#  'tab:gray': '#7f7f7f',
#  'tab:olive': '#bcbd22',
#  'tab:cyan': '#17becf'}

# %%
plot_colors(matplotlib.colors.TABLEAU_COLORS,90)

# %%
# !pip install squarify
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import matplotlib.pyplot as plt
import squarify

matplotlib.rcParams['figure.figsize']=(15,10)

def plot_colors2(colors):
    size=[1]*len(colors)
    label=colors.values()
    color=colors.values()
    
    squarify.plot(sizes = size, label = label, color = color)
    plt.axis('off')
    
plot_colors2(matplotlib.colors.CSS4_COLORS)
