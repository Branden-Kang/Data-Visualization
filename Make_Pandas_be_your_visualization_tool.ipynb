# %% [markdown]
# [Reference](https://towardsdev.com/make-pandas-be-your-visualization-tool-part-i-ad1afa8e5889)

# %%
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd
from pandas import DataFrame,Series
plt.style.use('dark_background')#set the background color

# %%
np.random.seed(0)
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2023", periods=1000))
ts1 = ts.cumsum()
ts1.plot()#Liner by default
# Out:
# <Axes: >

# %%
np.random.seed(0)
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list("ABCD"))
df = df.cumsum()
df.plot()
# Out:
# <Axes: >

# %%
df.iloc[5].plot(kind="bar")
# Out:
# <Axes: >

# %%
df2 = pd.DataFrame(np.random.rand(10, 4), columns=["a", "b", "c", "d"])
df2.plot.bar()
# Out:
# <Axes: >

# %%
df2.plot.bar(stacked=True)
# Out:
# <Axes: >

# %%
df2.plot.barh(stacked=True)
# Out:
# <Axes: >

# %%
df4 = pd.DataFrame(
    {
        "a": np.random.randn(1000) + 1,
        "b": np.random.randn(1000),
        "c": np.random.randn(1000) - 1,
    },
    columns=["a", "b", "c"],
)
df4.plot.hist(alpha=0.8)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.diff().hist(color="r", alpha=0.9, bins=50)
# Out:
# array([[<Axes: title={'center': 'A'}>, <Axes: title={'center': 'B'}>],
#        [<Axes: title={'center': 'C'}>, <Axes: title={'center': 'D'}>]],
#       dtype=object)

# %%
df = pd.DataFrame(np.random.rand(10, 5), columns=["A", "B", "C", "D", "E"])
df.plot.box()
# Out:
# <Axes: >

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=["a", "b", "c", "d"])
df.plot.area()
# Out:
# <Axes: >

# %%
df.plot.area(stacked=False)
# Out:
# <Axes: >

# %%
ax = df.plot.scatter(x="a", y="b", color="r", label="Group 1",s=90)
df.plot.scatter(x="c", y="d", color="g", label="Group 2", ax=ax,s=90)
# Out:
# <Axes: xlabel='c', ylabel='d'>
