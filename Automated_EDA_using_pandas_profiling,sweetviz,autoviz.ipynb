# %% [markdown]
# [Reference](https://medium.com/analytics-vidhya/automated-eda-using-pandas-profiling-sweetviz-autoviz-4f15c4031a12)

# %%
# !pip install autoviz
# Out:
# ...
#      |████████████████████████████████| 46 kB 2.2 MB/s
# ...
#      |████████████████████████████████| 3.1 MB 9.8 MB/s
# ...

# %%
# Run this cell and select the kaggle.json file downloaded
# from the Kaggle account settings page.
from google.colab import files
files.upload()

# %%
# Next, install the Kaggle API client. install -q kaggle
# The Kaggle API client expects this file to be in ~/.kaggle, so move it there.
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/# This permissions change avoids a warning on Kaggle tool startup.
# !chmod 600 ~/.kaggle/kaggle.json
# Searching for dataset
# !kaggle datasets list -s weather-dataset-rattle-package
# Downloading dataset and coming out of directory
# !kaggle datasets download jsphyg/weather-dataset-rattle-package
# Unzipping downloaded file and removing unusable file
# !unzip weather-dataset-rattle-package.zip
# !rm weather-dataset-rattle-package.zip

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()
# Out:
# Imported AutoViz_Class version: 0.0.85. Call using:
#     AV = AutoViz_Class()
#     AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=0,
#                             lowess=False,chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30)
# Note: verbose=0 or 1 generates charts and displays them in your local Jupyter notebook.
#       verbose=2 does not show plot but creates them and saves them in AutoViz_Plots directory in your local machine.

# %%
df = AV.AutoViz("https://raw.githubusercontent.com/Branden-Kang/Python-practice/master/Data/WeatherDataM.csv")
# Out:
# Shape of your Data Set loaded: (50, 4)
# ############## C L A S S I F Y I N G  V A R I A B L E S  ####################
# Classifying variables in data set...
#     4 Predictors classified...
#         This does not include the Target column(s)
#         No variables removed since no ID or low-information variables found in data set
# Number of All Scatter Plots = 10
# No categorical or numeric vars in data set. Hence no bar charts.
# Time to run AutoViz (in seconds) = 6
#
#  ###################### VISUALIZATION Completed ########################

# %%
from sklearn.datasets import load_boston
import pandas as pd
boston = load_boston()

# %%
# boston data로 feature 생성
data = pd.DataFrame(boston.data, columns=boston.feature_names)

# boston data의 target 값도 추가
data['MEDV'] = pd.Series(data=boston.target, index=data.index)

# %%
data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX  ...    TAX  PTRATIO       B  LSTAT  MEDV
# 0    0.00632  18.0   2.31   0.0  0.538  ...  296.0     15.3  396.90   4.98  24.0
# 1    0.02731   0.0   7.07   0.0  0.469  ...  242.0     17.8  396.90   9.14  21.6
# 2    0.02729   0.0   7.07   0.0  0.469  ...  242.0     17.8  392.83   4.03  34.7
# 3    0.03237   0.0   2.18   0.0  0.458  ...  222.0     18.7  394.63   2.94  33.4
# 4    0.06905   0.0   2.18   0.0  0.458  ...  222.0     18.7  396.90   5.33  36.2
# ..       ...   ...    ...   ...    ...  ...    ...      ...     ...    ...   ...
# 501  0.06263   0.0  11.93   0.0  0.573  ...  273.0     21.0  391.99   9.67  22.4
# 502  0.04527   0.0  11.93   0.0  0.573  ...  273.0     21.0  396.90   9.08  20.6
# 503  0.06076   0.0  11.93   0.0  0.573  ...  273.0     21.0  396.90   5.64  23.9
# 504  0.10959   0.0  11.93   0.0  0.573  ...  273.0     21.0  393.45   6.48  22.0
# 505  0.04741   0.0  11.93   0.0  0.573  ...  273.0     21.0  396.90   7.88  11.9
#
# ...

# %%
data.to_csv('boston.csv',index=False)

# %%
pd.read_csv('boston.csv').columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
df = AV.AutoViz('boston.csv', depVar='MEDV')
# Out:
# Shape of your Data Set loaded: (506, 14)
# ############## C L A S S I F Y I N G  V A R I A B L E S  ####################
# Classifying variables in data set...
#     13 Predictors classified...
#         This does not include the Target column(s)
#         No variables removed since no ID or low-information variables found in data set
#
# ################ Regression VISUALIZATION Started #####################
# Number of All Scatter Plots = 78
# No categorical or numeric vars in data set. Hence no bar charts.
# All Plots done
# Time to run AutoViz (in seconds) = 39
#
#  ###################### VISUALIZATION Completed ########################
